# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps    

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
        
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class SiameseNetworkDataset(Dataset):
    def __init__(self,imageFolderDataset,transform=None):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)

        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] == img1_tuple[1]:
                    break
        else:

            while True:
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] != img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])

        img0 = img0.convert("L")
        img1 = img1.convert("L")

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1, torch.from_numpy(np.array([int(img1_tuple[1] != img0_tuple[1])], dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
# folder_dataset.samples.__len__()

# %%
transformation = transforms.Compose([transforms.Resize((100,100)),
                                     transforms.ToTensor()
                                    ])

siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transformation)

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)

# %%
# Extract one batch
example_batch = next(iter(vis_dataloader))

# Example batch is a list containing 2x8 images, indexes 0 and 1, an also the label
# If the label is 1, it means that it is not the same person, label is 0, same person in both images
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [0. 1. 1. 0. 1. 1. 0. 1.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 96, kernel_size=11,stride=4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5, stride=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(256, 384, kernel_size=3,stride=1),
            nn.ReLU(inplace=True)
        )

        # Setting up the Fully Connected Layers
        self.fc1 = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(inplace=True),
            
            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),
            
            nn.Linear(256,2)
        )
        
    def forward_once(self, x):
        # This function will be called for both images
        # It's output is used to determine the similiarity
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # In this function we pass in both images and obtain both vectors
        # which are returned
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)

        return output1, output2

# %%
# Define the Contrastive Loss Function
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
      # Calculate the euclidian distance and calculate the contrastive loss
      euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)

      loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                    (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


      return loss_contrastive

# %%
# Load the training dataset
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=64)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# Iterate throught the epochs
for epoch in range(100):

    # Iterate over batches
    for i, (img0, img1, label) in enumerate(train_dataloader, 0):

        img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

        optimizer.zero_grad()

        output1, output2 = net(img0, img1)

        loss_contrastive = criterion(output1, output2, label)

        loss_contrastive.backward()

        # Optimize
        optimizer.step()

        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 1.8701212406158447
#
# Epoch number 0
#  Current loss 1.3352363109588623
#
# Epoch number 0
#  Current loss 0.9873251914978027
#
# Epoch number 0
#  Current loss 1.4277273416519165
#
# Epoch number 0
#  Current loss 1.0693185329437256
#
# Epoch number 0
#  Current loss 1.120741367340088
#
# Epoch number 0
#  Current loss 0.8705590963363647
#
# Epoch number 0
#  Current loss 0.9962014555931091
#
# Epoch number 0
#  Current loss 0.8538352251052856
#
# Epoch number 0
#  Current loss 0.9577503204345703
#
# Epoch number 0
#  Current loss 0.8124921321868896
#
# Epoch number 0
#  Current loss 0.6163199543952942
#
# Epoch number 0
#  Current loss 0.839245080947876
#
# Epoch number 1
#  Current loss 0.8818652629852295
#
# Epoch number 1
#  Current loss 0.9508611559867859
#
# Epoch number 1
#  Current loss 0.7808822393417358
#
# Epoch number 1
#  Current loss 0.5807711482048035
#
# Epoch number 1
#  Current loss 0.7064675092697144
#
# Epoch number 1
#  Current loss 0.9132670164108276
#
# Epoch number 1
#  Current loss 0.887190580368042
#
# Epoch number 1
#  Current loss 0.7222944498062134
#
# Epoch number 1
#  Current loss 0.8444814682006836
#
# Epoch number 1
#  Current loss 0.7362700700759888
#
# Epoch number 1
#  Current loss 0.7292701005935669
#
# Epoch number 1
#  Current loss 0.7483097314834595
#
# Epoch number 1
#  Current loss 0.8763566017150879
#
# Epoch number 2
#  Current loss 0.7118915319442749
#
# Epoch number 2
#  Current loss 0.7779738903045654
#
# Epoch number 2
#  Current loss 0.7119444012641907
#
# Epoch number 2
#  Current loss 0.7898764610290527
#
# Epoch number 2
#  Current loss 1.0465943813323975
#
# Epoch number 2
#  Current loss 0.8131210803985596
#
# Epoch number 2
#  Current loss 0.8086118698120117
#
# Epoch number 2
#  Current loss 0.8374155759811401
#
# Epoch number 2
#  Current loss 0.6849417090415955
#
# Epoch number 2
#  Current loss 0.9345609545707703
#
# Epoch number 2
#  Current loss 0.8565069437026978
#
# Epoch number 2
#  Current loss 0.7490437626838684
#
# Epoch number 2
#  Current loss 0.6580128073692322
#
# Epoch number 3
#  Current loss 0.7080957889556885
#
# Epoch number 3
#  Current loss 0.8179738521575928
#
# Epoch number 3
#  Current loss 0.7749969959259033
#
# Epoch number 3
#  Current loss 0.7577335834503174
#
# Epoch number 3
#  Current loss 0.6868747472763062
#
# Epoch number 3
#  Current loss 0.7564501762390137
#
# Epoch number 3
#  Current loss 0.8252211809158325
#
# Epoch number 3
#  Current loss 0.7532509565353394
#
# Epoch number 3
#  Current loss 0.8744823932647705
#
# Epoch number 3
#  Current loss 0.8190673589706421
#
# Epoch number 3
#  Current loss 0.5942285060882568
#
# Epoch number 3
#  Current loss 0.6219559907913208
#
# Epoch number 3
#  Current loss 0.710351288318634
#
# Epoch number 4
#  Current loss 0.6050816774368286
#
# Epoch number 4
#  Current loss 0.6094965934753418
#
# Epoch number 4
#  Current loss 0.7610177993774414
#
# Epoch number 4
#  Current loss 0.6612566709518433
#
# Epoch number 4
#  Current loss 0.7397726774215698
#
# Epoch number 4
#  Current loss 0.7620189189910889
#
# Epoch number 4
#  Current loss 0.6810213327407837
#
# Epoch number 4
#  Current loss 0.8770902156829834
#
# Epoch number 4
#  Current loss 0.6369422674179077
#
# Epoch number 4
#  Current loss 0.8188533782958984
#
# Epoch number 4
#  Current loss 0.6151901483535767
#
# Epoch number 4
#  Current loss 0.8415130376815796
#
# Epoch number 4
#  Current loss 0.5739824771881104
#
# Epoch number 5
#  Current loss 0.6639793515205383
#
# Epoch number 5
#  Current loss 0.6805847883224487
#
# Epoch number 5
#  Current loss 0.5679508447647095
#
# Epoch number 5
#  Current loss 0.6019604206085205
#
# Epoch number 5
#  Current loss 0.7427768707275391
#
# Epoch number 5
#  Current loss 0.698508620262146
#
# Epoch number 5
#  Current loss 0.4645507335662842
#
# Epoch number 5
#  Current loss 0.5842282176017761
#
# Epoch number 5
#  Current loss 0.6767199039459229
#
# Epoch number 5
#  Current loss 0.6561469435691833
#
# Epoch number 5
#  Current loss 0.7389699816703796
#
# Epoch number 5
#  Current loss 0.7872487306594849
#
# Epoch number 5
#  Current loss 0.7854817509651184
#
# Epoch number 6
#  Current loss 0.7540591955184937
#
# Epoch number 6
#  Current loss 0.5307199954986572
#
# Epoch number 6
#  Current loss 0.5939077138900757
#
# Epoch number 6
#  Current loss 0.6540532112121582
#
# Epoch number 6
#  Current loss 0.5386680364608765
#
# Epoch number 6
#  Current loss 0.5927054286003113
#
# Epoch number 6
#  Current loss 0.7229858040809631
#
# Epoch number 6
#  Current loss 0.7765170931816101
#
# Epoch number 6
#  Current loss 0.6016845703125
#
# Epoch number 6
#  Current loss 0.6399409174919128
#
# Epoch number 6
#  Current loss 0.7474628686904907
#
# Epoch number 6
#  Current loss 0.7692916393280029
#
# Epoch number 6
#  Current loss 0.8262719511985779
#
# Epoch number 7
#  Current loss 0.8587535619735718
#
# Epoch number 7
#  Current loss 0.8059329986572266
#
# Epoch number 7
#  Current loss 0.5121200084686279
#
# Epoch number 7
#  Current loss 0.6880146265029907
#
# Epoch number 7
#  Current loss 0.8647713661193848
#
# Epoch number 7
#  Current loss 0.7036954164505005
#
# Epoch number 7
#  Current loss 0.7148297429084778
#
# Epoch number 7
#  Current loss 0.7083675861358643
#
# Epoch number 7
#  Current loss 0.7673159837722778
#
# Epoch number 7
#  Current loss 0.6826102137565613
#
# Epoch number 7
#  Current loss 0.7943639755249023
#
# Epoch number 7
#  Current loss 0.754765510559082
#
# Epoch number 7
#  Current loss 0.5752416849136353
#
# Epoch number 8
#  Current loss 0.4850233793258667
#
# Epoch number 8
#  Current loss 0.5332271456718445
#
# Epoch number 8
#  Current loss 0.5645942687988281
#
# Epoch number 8
#  Current loss 0.5491846799850464
#
# Epoch number 8
#  Current loss 0.6572420001029968
#
# Epoch number 8
#  Current loss 0.6879693865776062
#
# Epoch number 8
#  Current loss 0.7375243902206421
#
# Epoch number 8
#  Current loss 0.7646435499191284
#
# Epoch number 8
#  Current loss 0.9744930267333984
#
# Epoch number 8
#  Current loss 0.5244923830032349
#
# Epoch number 8
#  Current loss 0.71009361743927
#
# Epoch number 8
#  Current loss 0.6477158069610596
#
# Epoch number 8
#  Current loss 0.5251572728157043
#
# Epoch number 9
#  Current loss 0.6773427724838257
#
# Epoch number 9
#  Current loss 0.5186765193939209
#
# Epoch number 9
#  Current loss 0.464704692363739
#
# Epoch number 9
#  Current loss 0.5648049116134644
#
# Epoch number 9
#  Current loss 0.6968272924423218
#
# Epoch number 9
#  Current loss 0.5662822723388672
#
# Epoch number 9
#  Current loss 0.6391320824623108
#
# Epoch number 9
#  Current loss 0.5481284856796265
#
# Epoch number 9
#  Current loss 0.5710930228233337
#
# Epoch number 9
#  Current loss 0.6287680268287659
#
# Epoch number 9
#  Current loss 0.7455552816390991
#
# Epoch number 9
#  Current loss 0.5716810822486877
#
# Epoch number 9
#  Current loss 0.6938942670822144
#
# Epoch number 10
#  Current loss 0.6348202228546143
#
# Epoch number 10
#  Current loss 0.5057884454727173
#
# Epoch number 10
#  Current loss 0.5127973556518555
#
# Epoch number 10
#  Current loss 0.7757444381713867
#
# Epoch number 10
#  Current loss 0.5401896834373474
#
# Epoch number 10
#  Current loss 0.40653544664382935
#
# Epoch number 10
#  Current loss 0.7277289628982544
#
# Epoch number 10
#  Current loss 0.7648306488990784
#
# Epoch number 10
#  Current loss 0.6170858144760132
#
# Epoch number 10
#  Current loss 0.6735919713973999
#
# Epoch number 10
#  Current loss 0.8730179667472839
#
# Epoch number 10
#  Current loss 0.6517789363861084
#
# Epoch number 10
#  Current loss 0.5206815600395203
#
# Epoch number 11
#  Current loss 0.5588347911834717
#
# Epoch number 11
#  Current loss 0.7443917989730835
#
# Epoch number 11
#  Current loss 0.7535699009895325
#
# Epoch number 11
#  Current loss 0.8632005453109741
#
# Epoch number 11
#  Current loss 0.748337984085083
#
# Epoch number 11
#  Current loss 0.6359347105026245
#
# Epoch number 11
#  Current loss 0.6712405681610107
#
# Epoch number 11
#  Current loss 0.6326682567596436
#
# Epoch number 11
#  Current loss 0.5379462242126465
#
# Epoch number 11
#  Current loss 0.6407449245452881
#
# Epoch number 11
#  Current loss 0.5861871242523193
#
# Epoch number 11
#  Current loss 0.8265894055366516
#
# Epoch number 11
#  Current loss 0.6199734807014465
#
# Epoch number 12
#  Current loss 0.6210610866546631
#
# Epoch number 12
#  Current loss 0.5950303673744202
#
# Epoch number 12
#  Current loss 0.9388382434844971
#
# Epoch number 12
#  Current loss 0.6760481595993042
#
# Epoch number 12
#  Current loss 0.90777587890625
#
# Epoch number 12
#  Current loss 0.6353809833526611
#
# Epoch number 12
#  Current loss 0.5630558729171753
#
# Epoch number 12
#  Current loss 0.5905681848526001
#
# Epoch number 12
#  Current loss 0.5041157603263855
#
# Epoch number 12
#  Current loss 0.499138742685318
#
# Epoch number 12
#  Current loss 0.64299476146698
#
# Epoch number 12
#  Current loss 0.6727207899093628
#
# Epoch number 12
#  Current loss 0.7280491590499878
#
# Epoch number 13
#  Current loss 0.6637908220291138
#
# Epoch number 13
#  Current loss 0.5868581533432007
#
# Epoch number 13
#  Current loss 0.4844219386577606
#
# Epoch number 13
#  Current loss 0.7431262731552124
#
# Epoch number 13
#  Current loss 0.49069148302078247
#
# Epoch number 13
#  Current loss 0.6188859939575195
#
# Epoch number 13
#  Current loss 0.5561285018920898
#
# Epoch number 13
#  Current loss 0.6655030250549316
#
# Epoch number 13
#  Current loss 0.5925264358520508
#
# Epoch number 13
#  Current loss 0.6314425468444824
#
# Epoch number 13
#  Current loss 0.5855198502540588
#
# Epoch number 13
#  Current loss 0.5122686624526978
#
# Epoch number 13
#  Current loss 0.5066443681716919
#
# Epoch number 14
#  Current loss 0.5274466276168823
#
# Epoch number 14
#  Current loss 0.6824783086776733
#
# Epoch number 14
#  Current loss 0.6629990935325623
#
# Epoch number 14
#  Current loss 0.5381311178207397
#
# Epoch number 14
#  Current loss 0.6022762656211853
#
# Epoch number 14
#  Current loss 0.5043565630912781
#
# Epoch number 14
#  Current loss 0.31303712725639343
#
# Epoch number 14
#  Current loss 0.26860132813453674
#
# Epoch number 14
#  Current loss 0.487309068441391
#
# Epoch number 14
#  Current loss 0.8465152978897095
#
# Epoch number 14
#  Current loss 0.7242834568023682
#
# Epoch number 14
#  Current loss 0.44855183362960815
#
# Epoch number 14
#  Current loss 0.7001039385795593
#
# Epoch number 15
#  Current loss 0.5677822232246399
#
# Epoch number 15
#  Current loss 0.5145845413208008
#
# Epoch number 15
#  Current loss 0.46417123079299927
#
# Epoch number 15
#  Current loss 0.7026005983352661
#
# Epoch number 15
#  Current loss 0.5184232592582703
#
# Epoch number 15
#  Current loss 0.6104313135147095
#
# Epoch number 15
#  Current loss 0.6452934145927429
#
# Epoch number 15
#  Current loss 0.7026036977767944
#
# Epoch number 15
#  Current loss 0.5547367930412292
#
# Epoch number 15
#  Current loss 0.5662148594856262
#
# Epoch number 15
#  Current loss 0.46365803480148315
#
# Epoch number 15
#  Current loss 0.7344290018081665
#
# Epoch number 15
#  Current loss 0.6486155986785889
#
# Epoch number 16
#  Current loss 0.4968529939651489
#
# Epoch number 16
#  Current loss 0.6935926675796509
#
# Epoch number 16
#  Current loss 0.6766834855079651
#
# Epoch number 16
#  Current loss 0.5539125204086304
#
# Epoch number 16
#  Current loss 0.6861613392829895
#
# Epoch number 16
#  Current loss 0.6920731067657471
#
# Epoch number 16
#  Current loss 0.5298252701759338
#
# Epoch number 16
#  Current loss 0.7711172103881836
#
# Epoch number 16
#  Current loss 0.6727300882339478
#
# Epoch number 16
#  Current loss 0.7568791508674622
#
# Epoch number 16
#  Current loss 0.605207622051239
#
# Epoch number 16
#  Current loss 0.5229349136352539
#
# Epoch number 16
#  Current loss 0.6526467800140381
#
# Epoch number 17
#  Current loss 0.5583378076553345
#
# Epoch number 17
#  Current loss 0.8381432890892029
#
# Epoch number 17
#  Current loss 0.7047675848007202
#
# Epoch number 17
#  Current loss 0.5583928823471069
#
# Epoch number 17
#  Current loss 0.4552890956401825
#
# Epoch number 17
#  Current loss 0.5294022560119629
#
# Epoch number 17
#  Current loss 0.5511549711227417
#
# Epoch number 17
#  Current loss 0.5646564960479736
#
# Epoch number 17
#  Current loss 0.590933084487915
#
# Epoch number 17
#  Current loss 0.6308475732803345
#
# Epoch number 17
#  Current loss 0.6400544047355652
#
# Epoch number 17
#  Current loss 0.7059293985366821
#
# Epoch number 17
#  Current loss 0.3553430438041687
#
# Epoch number 18
#  Current loss 0.7432206869125366
#
# Epoch number 18
#  Current loss 0.6847286224365234
#
# Epoch number 18
#  Current loss 0.6604424715042114
#
# Epoch number 18
#  Current loss 0.665015459060669
#
# Epoch number 18
#  Current loss 0.6140550971031189
#
# Epoch number 18
#  Current loss 0.6752843856811523
#
# Epoch number 18
#  Current loss 0.5006099939346313
#
# Epoch number 18
#  Current loss 0.6769623756408691
#
# Epoch number 18
#  Current loss 0.5545939207077026
#
# Epoch number 18
#  Current loss 0.5551091432571411
#
# Epoch number 18
#  Current loss 0.6525000333786011
#
# Epoch number 18
#  Current loss 0.6967946290969849
#
# Epoch number 18
#  Current loss 0.49870142340660095
#
# Epoch number 19
#  Current loss 0.5412905812263489
#
# Epoch number 19
#  Current loss 0.7061053514480591
#
# Epoch number 19
#  Current loss 0.5387436747550964
#
# Epoch number 19
#  Current loss 0.5204840898513794
#
# Epoch number 19
#  Current loss 0.8230078220367432
#
# Epoch number 19
#  Current loss 0.43489891290664673
#
# Epoch number 19
#  Current loss 0.5719092488288879
#
# Epoch number 19
#  Current loss 0.5425090789794922
#
# Epoch number 19
#  Current loss 0.5753997564315796
#
# Epoch number 19
#  Current loss 0.6979325413703918
#
# Epoch number 19
#  Current loss 0.45938336849212646
#
# Epoch number 19
#  Current loss 0.6194776296615601
#
# Epoch number 19
#  Current loss 0.4621398448944092
#
# Epoch number 20
#  Current loss 0.5093137621879578
#
# Epoch number 20
#  Current loss 0.47929075360298157
#
# Epoch number 20
#  Current loss 0.52516770362854
#
# Epoch number 20
#  Current loss 0.7199797630310059
#
# Epoch number 20
#  Current loss 0.5500957369804382
#
# Epoch number 20
#  Current loss 0.4987073540687561
#
# Epoch number 20
#  Current loss 0.7224828600883484
#
# Epoch number 20
#  Current loss 0.512130618095398
#
# Epoch number 20
#  Current loss 0.5936710834503174
#
# Epoch number 20
#  Current loss 0.5860198736190796
#
# Epoch number 20
#  Current loss 0.4139411449432373
#
# Epoch number 20
#  Current loss 0.5629044771194458
#
# Epoch number 20
#  Current loss 0.5945507287979126
#
# Epoch number 21
#  Current loss 0.48463886976242065
#
# Epoch number 21
#  Current loss 0.5172725319862366
#
# Epoch number 21
#  Current loss 0.6583812832832336
#
# Epoch number 21
#  Current loss 0.43521255254745483
#
# Epoch number 21
#  Current loss 0.5062445402145386
#
# Epoch number 21
#  Current loss 0.5493151545524597
#
# Epoch number 21
#  Current loss 0.5653810501098633
#
# Epoch number 21
#  Current loss 0.5982129573822021
#
# Epoch number 21
#  Current loss 0.4960966110229492
#
# Epoch number 21
#  Current loss 0.6282722353935242
#
# Epoch number 21
#  Current loss 0.6323464512825012
#
# Epoch number 21
#  Current loss 0.5736298561096191
#
# Epoch number 21
#  Current loss 0.5801740288734436
#
# Epoch number 22
#  Current loss 0.4927244186401367
#
# Epoch number 22
#  Current loss 0.3935861587524414
#
# Epoch number 22
#  Current loss 0.6773129105567932
#
# Epoch number 22
#  Current loss 0.5747535228729248
#
# Epoch number 22
#  Current loss 0.7002044916152954
#
# Epoch number 22
#  Current loss 0.44140636920928955
#
# Epoch number 22
#  Current loss 0.46157005429267883
#
# Epoch number 22
#  Current loss 0.47786644101142883
#
# Epoch number 22
#  Current loss 0.6546434164047241
#
# Epoch number 22
#  Current loss 0.45442554354667664
#
# Epoch number 22
#  Current loss 0.552275538444519
#
# Epoch number 22
#  Current loss 0.6043237447738647
#
# Epoch number 22
#  Current loss 0.6654492020606995
#
# Epoch number 23
#  Current loss 0.4548046588897705
#
# Epoch number 23
#  Current loss 0.49098867177963257
#
# Epoch number 23
#  Current loss 0.6073641777038574
#
# Epoch number 23
#  Current loss 0.7142229080200195
#
# Epoch number 23
#  Current loss 0.8175848722457886
#
# Epoch number 23
#  Current loss 0.5935649275779724
#
# Epoch number 23
#  Current loss 0.5677176713943481
#
# Epoch number 23
#  Current loss 0.5548231601715088
#
# Epoch number 23
#  Current loss 0.6977206468582153
#
# Epoch number 23
#  Current loss 0.6201767921447754
#
# Epoch number 23
#  Current loss 0.39448103308677673
#
# Epoch number 23
#  Current loss 0.53977370262146
#
# Epoch number 23
#  Current loss 0.43367791175842285
#
# Epoch number 24
#  Current loss 0.7974593639373779
#
# Epoch number 24
#  Current loss 0.5064123272895813
#
# Epoch number 24
#  Current loss 0.7047182321548462
#
# Epoch number 24
#  Current loss 0.6237159967422485
#
# Epoch number 24
#  Current loss 0.7738016843795776
#
# Epoch number 24
#  Current loss 0.49567896127700806
#
# Epoch number 24
#  Current loss 0.6728242039680481
#
# Epoch number 24
#  Current loss 0.5374802350997925
#
# Epoch number 24
#  Current loss 0.46468913555145264
#
# Epoch number 24
#  Current loss 0.7542705535888672
#
# Epoch number 24
#  Current loss 0.5518527030944824
#
# Epoch number 24
#  Current loss 0.5760399103164673
#
# Epoch number 24
#  Current loss 0.48911967873573303
#
# Epoch number 25
#  Current loss 0.4534965455532074
#
# Epoch number 25
#  Current loss 0.7262349724769592
#
# Epoch number 25
#  Current loss 0.4957858622074127
#
# Epoch number 25
#  Current loss 0.5753971934318542
#
# Epoch number 25
#  Current loss 0.57203209400177
#
# Epoch number 25
#  Current loss 0.5356881022453308
#
# Epoch number 25
#  Current loss 0.6714455485343933
#
# Epoch number 25
#  Current loss 0.6457170844078064
#
# Epoch number 25
#  Current loss 0.6113139390945435
#
# Epoch number 25
#  Current loss 0.7414892911911011
#
# Epoch number 25
#  Current loss 0.48193928599357605
#
# Epoch number 25
#  Current loss 0.749159574508667
#
# Epoch number 25
#  Current loss 0.6357158422470093
#
# Epoch number 26
#  Current loss 0.5987535119056702
#
# Epoch number 26
#  Current loss 0.6887324452400208
#
# Epoch number 26
#  Current loss 0.5245157480239868
#
# Epoch number 26
#  Current loss 0.6855118274688721
#
# Epoch number 26
#  Current loss 0.5441957116127014
#
# Epoch number 26
#  Current loss 0.674773097038269
#
# Epoch number 26
#  Current loss 0.47504061460494995
#
# Epoch number 26
#  Current loss 0.5170431137084961
#
# Epoch number 26
#  Current loss 0.5962095260620117
#
# Epoch number 26
#  Current loss 0.43502944707870483
#
# Epoch number 26
#  Current loss 0.5731401443481445
#
# Epoch number 26
#  Current loss 0.6104788780212402
#
# Epoch number 26
#  Current loss 0.4992007613182068
#
# Epoch number 27
#  Current loss 0.6301858425140381
#
# Epoch number 27
#  Current loss 0.44401952624320984
#
# Epoch number 27
#  Current loss 0.47154247760772705
#
# Epoch number 27
#  Current loss 0.7288798093795776
#
# Epoch number 27
#  Current loss 0.4731035828590393
#
# Epoch number 27
#  Current loss 0.7416963577270508
#
# Epoch number 27
#  Current loss 0.5482012033462524
#
# Epoch number 27
#  Current loss 0.5101948976516724
#
# Epoch number 27
#  Current loss 0.5083574056625366
#
# Epoch number 27
#  Current loss 0.4402577877044678
#
# Epoch number 27
#  Current loss 0.5713422894477844
#
# Epoch number 27
#  Current loss 0.5786219835281372
#
# Epoch number 27
#  Current loss 0.5270671248435974
#
# Epoch number 28
#  Current loss 0.41606318950653076
#
# Epoch number 28
#  Current loss 0.469653844833374
#
# Epoch number 28
#  Current loss 0.5746464729309082
#
# Epoch number 28
#  Current loss 0.6648663878440857
#
# Epoch number 28
#  Current loss 0.5209609270095825
#
# Epoch number 28
#  Current loss 0.46134889125823975
#
# Epoch number 28
#  Current loss 0.46934860944747925
#
# Epoch number 28
#  Current loss 0.585331916809082
#
# Epoch number 28
#  Current loss 0.6989191770553589
#
# Epoch number 28
#  Current loss 0.5509986281394958
#
# Epoch number 28
#  Current loss 0.47078466415405273
#
# Epoch number 28
#  Current loss 0.371116042137146
#
# Epoch number 28
#  Current loss 0.596489667892456
#
# Epoch number 29
#  Current loss 0.5754340887069702
#
# Epoch number 29
#  Current loss 0.5760247707366943
#
# Epoch number 29
#  Current loss 0.42349106073379517
#
# Epoch number 29
#  Current loss 0.5012645721435547
#
# Epoch number 29
#  Current loss 0.48067307472229004
#
# Epoch number 29
#  Current loss 0.47640669345855713
#
# Epoch number 29
#  Current loss 0.6174417734146118
#
# Epoch number 29
#  Current loss 0.5659540295600891
#
# Epoch number 29
#  Current loss 0.5743119716644287
#
# Epoch number 29
#  Current loss 0.6905896067619324
#
# Epoch number 29
#  Current loss 0.4538268744945526
#
# Epoch number 29
#  Current loss 0.6166149377822876
#
# Epoch number 29
#  Current loss 0.4981004595756531
#
# Epoch number 30
#  Current loss 0.4240184724330902
#
# Epoch number 30
#  Current loss 0.43669986724853516
#
# Epoch number 30
#  Current loss 0.43915534019470215
#
# Epoch number 30
#  Current loss 0.5960004329681396
#
# Epoch number 30
#  Current loss 0.43753284215927124
#
# Epoch number 30
#  Current loss 0.569661021232605
#
# Epoch number 30
#  Current loss 0.37249261140823364
#
# Epoch number 30
#  Current loss 0.5277231931686401
#
# Epoch number 30
#  Current loss 0.5680249333381653
#
# Epoch number 30
#  Current loss 0.41208386421203613
#
# Epoch number 30
#  Current loss 0.44481635093688965
#
# Epoch number 30
#  Current loss 0.5332129001617432
#
# Epoch number 30
#  Current loss 0.6087359189987183
#
# Epoch number 31
#  Current loss 0.4354232847690582
#
# Epoch number 31
#  Current loss 0.6603220701217651
#
# Epoch number 31
#  Current loss 0.4174932837486267
#
# Epoch number 31
#  Current loss 0.49941787123680115
#
# Epoch number 31
#  Current loss 0.42837727069854736
#
# Epoch number 31
#  Current loss 0.5380957126617432
#
# Epoch number 31
#  Current loss 0.40651410818099976
#
# Epoch number 31
#  Current loss 0.6717577576637268
#
# Epoch number 31
#  Current loss 0.6105316281318665
#
# Epoch number 31
#  Current loss 0.4787234663963318
#
# Epoch number 31
#  Current loss 0.554511308670044
#
# Epoch number 31
#  Current loss 0.43803107738494873
#
# Epoch number 31
#  Current loss 0.372019499540329
#
# Epoch number 32
#  Current loss 0.41661643981933594
#
# Epoch number 32
#  Current loss 0.5993672013282776
#
# Epoch number 32
#  Current loss 0.39539217948913574
#
# Epoch number 32
#  Current loss 0.49752163887023926
#
# Epoch number 32
#  Current loss 0.5156974196434021
#
# Epoch number 32
#  Current loss 0.48240041732788086
#
# Epoch number 32
#  Current loss 0.5888619422912598
#
# Epoch number 32
#  Current loss 0.46887722611427307
#
# Epoch number 32
#  Current loss 0.5392042398452759
#
# Epoch number 32
#  Current loss 0.571915328502655
#
# Epoch number 32
#  Current loss 0.5003859996795654
#
# Epoch number 32
#  Current loss 0.5881263017654419
#
# Epoch number 32
#  Current loss 0.4352092146873474
#
# Epoch number 33
#  Current loss 0.6380279660224915
#
# Epoch number 33
#  Current loss 0.5304993987083435
#
# Epoch number 33
#  Current loss 0.6509205102920532
#
# Epoch number 33
#  Current loss 0.4802214205265045
#
# Epoch number 33
#  Current loss 0.652326226234436
#
# Epoch number 33
#  Current loss 0.49142736196517944
#
# Epoch number 33
#  Current loss 0.6555137038230896
#
# Epoch number 33
#  Current loss 0.4268872141838074
#
# Epoch number 33
#  Current loss 0.48624640703201294
#
# Epoch number 33
#  Current loss 0.49825480580329895
#
# Epoch number 33
#  Current loss 0.4942306876182556
#
# Epoch number 33
#  Current loss 0.49783751368522644
#
# Epoch number 33
#  Current loss 0.4553719162940979
#
# Epoch number 34
#  Current loss 0.4393426775932312
#
# Epoch number 34
#  Current loss 0.460557222366333
#
# Epoch number 34
#  Current loss 0.4832681119441986
#
# Epoch number 34
#  Current loss 0.41551369428634644
#
# Epoch number 34
#  Current loss 0.6215333938598633
#
# Epoch number 34
#  Current loss 0.4269692897796631
#
# Epoch number 34
#  Current loss 0.4356839656829834
#
# Epoch number 34
#  Current loss 0.43423932790756226
#
# Epoch number 34
#  Current loss 0.46265897154808044
#
# Epoch number 34
#  Current loss 0.5420529246330261
#
# Epoch number 34
#  Current loss 0.42509809136390686
#
# Epoch number 34
#  Current loss 0.6734838485717773
#
# Epoch number 34
#  Current loss 0.48498138785362244
#
# Epoch number 35
#  Current loss 0.46083536744117737
#
# Epoch number 35
#  Current loss 0.5118784308433533
#
# Epoch number 35
#  Current loss 0.6616295576095581
#
# Epoch number 35
#  Current loss 0.607243537902832
#
# Epoch number 35
#  Current loss 0.3660612106323242
#
# Epoch number 35
#  Current loss 0.5259574055671692
#
# Epoch number 35
#  Current loss 0.5250994563102722
#
# Epoch number 35
#  Current loss 0.5667035579681396
#
# Epoch number 35
#  Current loss 0.4750579595565796
#
# Epoch number 35
#  Current loss 0.3536856472492218
#
# Epoch number 35
#  Current loss 0.49264076352119446
#
# Epoch number 35
#  Current loss 0.46582940220832825
#
# Epoch number 35
#  Current loss 0.52992182970047
#
# Epoch number 36
#  Current loss 0.45408767461776733
#
# Epoch number 36
#  Current loss 0.6930770874023438
#
# Epoch number 36
#  Current loss 0.49762097001075745
#
# Epoch number 36
#  Current loss 0.4982103705406189
#
# Epoch number 36
#  Current loss 0.575423002243042
#
# Epoch number 36
#  Current loss 0.46974894404411316
#
# Epoch number 36
#  Current loss 0.5897238850593567
#
# Epoch number 36
#  Current loss 0.6321346759796143
#
# Epoch number 36
#  Current loss 0.46559441089630127
#
# Epoch number 36
#  Current loss 0.5122092962265015
#
# Epoch number 36
#  Current loss 0.5581856966018677
#
# Epoch number 36
#  Current loss 0.41021373867988586
#
# Epoch number 36
#  Current loss 0.42275840044021606
#
# Epoch number 37
#  Current loss 0.5089894533157349
#
# Epoch number 37
#  Current loss 0.5503129363059998
#
# Epoch number 37
#  Current loss 0.534782886505127
#
# Epoch number 37
#  Current loss 0.5149560570716858
#
# Epoch number 37
#  Current loss 0.42976289987564087
#
# Epoch number 37
#  Current loss 0.6015644669532776
#
# Epoch number 37
#  Current loss 0.3937746584415436
#
# Epoch number 37
#  Current loss 0.5238786935806274
#
# Epoch number 37
#  Current loss 0.48048126697540283
#
# Epoch number 37
#  Current loss 0.43830570578575134
#
# Epoch number 37
#  Current loss 0.5024145841598511
#
# Epoch number 37
#  Current loss 0.475689172744751
#
# Epoch number 37
#  Current loss 0.4197259843349457
#
# Epoch number 38
#  Current loss 0.5365430116653442
#
# Epoch number 38
#  Current loss 0.5650277137756348
#
# Epoch number 38
#  Current loss 0.6538541316986084
#
# Epoch number 38
#  Current loss 0.5381619930267334
#
# Epoch number 38
#  Current loss 0.5117098093032837
#
# Epoch number 38
#  Current loss 0.47056400775909424
#
# Epoch number 38
#  Current loss 0.5056983232498169
#
# Epoch number 38
#  Current loss 0.5914367437362671
#
# Epoch number 38
#  Current loss 0.45034173130989075
#
# Epoch number 38
#  Current loss 0.4627259373664856
#
# Epoch number 38
#  Current loss 0.34372231364250183
#
# Epoch number 38
#  Current loss 0.3740740418434143
#
# Epoch number 38
#  Current loss 0.4863888621330261
#
# Epoch number 39
#  Current loss 0.39927470684051514
#
# Epoch number 39
#  Current loss 0.38075777888298035
#
# Epoch number 39
#  Current loss 0.5319149494171143
#
# Epoch number 39
#  Current loss 0.38223111629486084
#
# Epoch number 39
#  Current loss 0.44000864028930664
#
# Epoch number 39
#  Current loss 0.6363061666488647
#
# Epoch number 39
#  Current loss 0.5363765954971313
#
# Epoch number 39
#  Current loss 0.6377369165420532
#
# Epoch number 39
#  Current loss 0.3986297845840454
#
# Epoch number 39
#  Current loss 0.3268135190010071
#
# Epoch number 39
#  Current loss 0.4121631383895874
#
# Epoch number 39
#  Current loss 0.3738946318626404
#
# Epoch number 39
#  Current loss 0.49398404359817505
#
# Epoch number 40
#  Current loss 0.4248120188713074
#
# Epoch number 40
#  Current loss 0.4845350980758667
#
# Epoch number 40
#  Current loss 0.41858822107315063
#
# Epoch number 40
#  Current loss 0.4563254714012146
#
# Epoch number 40
#  Current loss 0.5032132267951965
#
# Epoch number 40
#  Current loss 0.4142698645591736
#
# Epoch number 40
#  Current loss 0.3280349373817444
#
# Epoch number 40
#  Current loss 0.43657636642456055
#
# Epoch number 40
#  Current loss 0.28136178851127625
#
# Epoch number 40
#  Current loss 0.44926631450653076
#
# Epoch number 40
#  Current loss 0.6057102680206299
#
# Epoch number 40
#  Current loss 0.5892521142959595
#
# Epoch number 40
#  Current loss 0.429206520318985
#
# Epoch number 41
#  Current loss 0.47576773166656494
#
# Epoch number 41
#  Current loss 0.5932642221450806
#
# Epoch number 41
#  Current loss 0.5049901008605957
#
# Epoch number 41
#  Current loss 0.4348496198654175
#
# Epoch number 41
#  Current loss 0.566216230392456
#
# Epoch number 41
#  Current loss 0.5476128458976746
#
# Epoch number 41
#  Current loss 0.5050480365753174
#
# Epoch number 41
#  Current loss 0.446849524974823
#
# Epoch number 41
#  Current loss 0.45635634660720825
#
# Epoch number 41
#  Current loss 0.45258840918540955
#
# Epoch number 41
#  Current loss 0.3619375228881836
#
# Epoch number 41
#  Current loss 0.6021941900253296
#
# Epoch number 41
#  Current loss 0.6530691385269165
#
# Epoch number 42
#  Current loss 0.5082603693008423
#
# Epoch number 42
#  Current loss 0.4432808458805084
#
# Epoch number 42
#  Current loss 0.5532864928245544
#
# Epoch number 42
#  Current loss 0.5267598628997803
#
# Epoch number 42
#  Current loss 0.5662127733230591
#
# Epoch number 42
#  Current loss 0.4589027762413025
#
# Epoch number 42
#  Current loss 0.4887706935405731
#
# Epoch number 42
#  Current loss 0.4593057632446289
#
# Epoch number 42
#  Current loss 0.5414667725563049
#
# Epoch number 42
#  Current loss 0.5132735967636108
#
# Epoch number 42
#  Current loss 0.4357854127883911
#
# Epoch number 42
#  Current loss 0.414225697517395
#
# Epoch number 42
#  Current loss 0.31689339876174927
#
# Epoch number 43
#  Current loss 0.42151975631713867
#
# Epoch number 43
#  Current loss 0.43954503536224365
#
# Epoch number 43
#  Current loss 0.4611217975616455
#
# Epoch number 43
#  Current loss 0.330755352973938
#
# Epoch number 43
#  Current loss 0.5548276305198669
#
# Epoch number 43
#  Current loss 0.43953004479408264
#
# Epoch number 43
#  Current loss 0.41541001200675964
#
# Epoch number 43
#  Current loss 0.5950114727020264
#
# Epoch number 43
#  Current loss 0.39518818259239197
#
# Epoch number 43
#  Current loss 0.4575991630554199
#
# Epoch number 43
#  Current loss 0.6742808818817139
#
# Epoch number 43
#  Current loss 0.5048956871032715
#
# Epoch number 43
#  Current loss 0.40318161249160767
#
# Epoch number 44
#  Current loss 0.3634289503097534
#
# Epoch number 44
#  Current loss 0.5739118456840515
#
# Epoch number 44
#  Current loss 0.49615904688835144
#
# Epoch number 44
#  Current loss 0.578205406665802
#
# Epoch number 44
#  Current loss 0.48150938749313354
#
# Epoch number 44
#  Current loss 0.49343341588974
#
# Epoch number 44
#  Current loss 0.5786866545677185
#
# Epoch number 44
#  Current loss 0.48654377460479736
#
# Epoch number 44
#  Current loss 0.40588074922561646
#
# Epoch number 44
#  Current loss 0.30175113677978516
#
# Epoch number 44
#  Current loss 0.5859317183494568
#
# Epoch number 44
#  Current loss 0.4171521067619324
#
# Epoch number 44
#  Current loss 0.5317226052284241
#
# Epoch number 45
#  Current loss 0.4378321170806885
#
# Epoch number 45
#  Current loss 0.4055823087692261
#
# Epoch number 45
#  Current loss 0.606058657169342
#
# Epoch number 45
#  Current loss 0.3401559293270111
#
# Epoch number 45
#  Current loss 0.38575854897499084
#
# Epoch number 45
#  Current loss 0.4671775996685028
#
# Epoch number 45
#  Current loss 0.4494127333164215
#
# Epoch number 45
#  Current loss 0.39887821674346924
#
# Epoch number 45
#  Current loss 0.566033124923706
#
# Epoch number 45
#  Current loss 0.437133252620697
#
# Epoch number 45
#  Current loss 0.4134945273399353
#
# Epoch number 45
#  Current loss 0.3963695764541626
#
# Epoch number 45
#  Current loss 0.39238598942756653
#
# Epoch number 46
#  Current loss 0.5450195074081421
#
# Epoch number 46
#  Current loss 0.6489823460578918
#
# Epoch number 46
#  Current loss 0.4924381375312805
#
# Epoch number 46
#  Current loss 0.48121824860572815
#
# Epoch number 46
#  Current loss 0.5750216245651245
#
# Epoch number 46
#  Current loss 0.4946012496948242
#
# Epoch number 46
#  Current loss 0.519870400428772
#
# Epoch number 46
#  Current loss 0.43354177474975586
#
# Epoch number 46
#  Current loss 0.6379737854003906
#
# Epoch number 46
#  Current loss 0.4957982897758484
#
# Epoch number 46
#  Current loss 0.43454721570014954
#
# Epoch number 46
#  Current loss 0.46454960107803345
#
# Epoch number 46
#  Current loss 0.5054501295089722
#
# Epoch number 47
#  Current loss 0.41427236795425415
#
# Epoch number 47
#  Current loss 0.28447258472442627
#
# Epoch number 47
#  Current loss 0.6249054074287415
#
# Epoch number 47
#  Current loss 0.4355585277080536
#
# Epoch number 47
#  Current loss 0.6364812850952148
#
# Epoch number 47
#  Current loss 0.5090944170951843
#
# Epoch number 47
#  Current loss 0.4730650782585144
#
# Epoch number 47
#  Current loss 0.4467354416847229
#
# Epoch number 47
#  Current loss 0.3755202293395996
#
# Epoch number 47
#  Current loss 0.47721537947654724
#
# Epoch number 47
#  Current loss 0.39303669333457947
#
# Epoch number 47
#  Current loss 0.39484861493110657
#
# Epoch number 47
#  Current loss 0.43531376123428345
#
# Epoch number 48
#  Current loss 0.5610656142234802
#
# Epoch number 48
#  Current loss 0.5111912488937378
#
# Epoch number 48
#  Current loss 0.36171358823776245
#
# Epoch number 48
#  Current loss 0.41871178150177
#
# Epoch number 48
#  Current loss 0.39005687832832336
#
# Epoch number 48
#  Current loss 0.4162176847457886
#
# Epoch number 48
#  Current loss 0.4156145751476288
#
# Epoch number 48
#  Current loss 0.6010751128196716
#
# Epoch number 48
#  Current loss 0.4824868440628052
#
# Epoch number 48
#  Current loss 0.43333297967910767
#
# Epoch number 48
#  Current loss 0.42616307735443115
#
# Epoch number 48
#  Current loss 0.33241134881973267
#
# Epoch number 48
#  Current loss 0.537893533706665
#
# Epoch number 49
#  Current loss 0.5040097236633301
#
# Epoch number 49
#  Current loss 0.5332752466201782
#
# Epoch number 49
#  Current loss 0.3249885141849518
#
# Epoch number 49
#  Current loss 0.39210110902786255
#
# Epoch number 49
#  Current loss 0.39093655347824097
#
# Epoch number 49
#  Current loss 0.46294286847114563
#
# Epoch number 49
#  Current loss 0.4196152687072754
#
# Epoch number 49
#  Current loss 0.3845953047275543
#
# Epoch number 49
#  Current loss 0.5304137468338013
#
# Epoch number 49
#  Current loss 0.4598560333251953
#
# Epoch number 49
#  Current loss 0.4747050106525421
#
# Epoch number 49
#  Current loss 0.5150464177131653
#
# Epoch number 49
#  Current loss 0.3234912157058716
#
# Epoch number 50
#  Current loss 0.49089646339416504
#
# Epoch number 50
#  Current loss 0.5987012386322021
#
# Epoch number 50
#  Current loss 0.4755517244338989
#
# Epoch number 50
#  Current loss 0.3557618260383606
#
# Epoch number 50
#  Current loss 0.259468138217926
#
# Epoch number 50
#  Current loss 0.33770766854286194
#
# Epoch number 50
#  Current loss 0.4171569347381592
#
# Epoch number 50
#  Current loss 0.35400235652923584
#
# Epoch number 50
#  Current loss 0.37787944078445435
#
# Epoch number 50
#  Current loss 0.4479629397392273
#
# Epoch number 50
#  Current loss 0.3323710560798645
#
# Epoch number 50
#  Current loss 0.47221648693084717
#
# Epoch number 50
#  Current loss 0.3637833595275879
#
# Epoch number 51
#  Current loss 0.38738858699798584
#
# Epoch number 51
#  Current loss 0.28185468912124634
#
# Epoch number 51
#  Current loss 0.465959757566452
#
# Epoch number 51
#  Current loss 0.537278950214386
#
# Epoch number 51
#  Current loss 0.33820974826812744
#
# Epoch number 51
#  Current loss 0.5010956525802612
#
# Epoch number 51
#  Current loss 0.4113501310348511
#
# Epoch number 51
#  Current loss 0.4840879440307617
#
# Epoch number 51
#  Current loss 0.6732290387153625
#
# Epoch number 51
#  Current loss 0.49598807096481323
#
# Epoch number 51
#  Current loss 0.500100314617157
#
# Epoch number 51
#  Current loss 0.3597763478755951
#
# Epoch number 51
#  Current loss 0.40034350752830505
#
# Epoch number 52
#  Current loss 0.4213995337486267
#
# Epoch number 52
#  Current loss 0.4038808345794678
#
# Epoch number 52
#  Current loss 0.4103943109512329
#
# Epoch number 52
#  Current loss 0.4018446207046509
#
# Epoch number 52
#  Current loss 0.37619879841804504
#
# Epoch number 52
#  Current loss 0.3665528893470764
#
# Epoch number 52
#  Current loss 0.2534666359424591
#
# Epoch number 52
#  Current loss 0.5792077779769897
#
# Epoch number 52
#  Current loss 0.3357599973678589
#
# Epoch number 52
#  Current loss 0.29501718282699585
#
# Epoch number 52
#  Current loss 0.6637461185455322
#
# Epoch number 52
#  Current loss 0.30179011821746826
#
# Epoch number 52
#  Current loss 0.42686840891838074
#
# Epoch number 53
#  Current loss 0.6085867881774902
#
# Epoch number 53
#  Current loss 0.5872412323951721
#
# Epoch number 53
#  Current loss 0.6068381667137146
#
# Epoch number 53
#  Current loss 0.39203742146492004
#
# Epoch number 53
#  Current loss 0.5606175661087036
#
# Epoch number 53
#  Current loss 0.46168726682662964
#
# Epoch number 53
#  Current loss 0.42671412229537964
#
# Epoch number 53
#  Current loss 0.5649620294570923
#
# Epoch number 53
#  Current loss 0.30664652585983276
#
# Epoch number 53
#  Current loss 0.3167845606803894
#
# Epoch number 53
#  Current loss 0.45526501536369324
#
# Epoch number 53
#  Current loss 0.3865355849266052
#
# Epoch number 53
#  Current loss 0.4389081597328186
#
# Epoch number 54
#  Current loss 0.43225133419036865
#
# Epoch number 54
#  Current loss 0.5310864448547363
#
# Epoch number 54
#  Current loss 0.421316921710968
#
# Epoch number 54
#  Current loss 0.437031626701355
#
# Epoch number 54
#  Current loss 0.47793054580688477
#
# Epoch number 54
#  Current loss 0.36845460534095764
#
# Epoch number 54
#  Current loss 0.5030776858329773
#
# Epoch number 54
#  Current loss 0.41815608739852905
#
# Epoch number 54
#  Current loss 0.37396565079689026
#
# Epoch number 54
#  Current loss 0.42788684368133545
#
# Epoch number 54
#  Current loss 0.36225825548171997
#
# Epoch number 54
#  Current loss 0.5905224680900574
#
# Epoch number 54
#  Current loss 0.41222724318504333
#
# Epoch number 55
#  Current loss 0.3669934868812561
#
# Epoch number 55
#  Current loss 0.6196304559707642
#
# Epoch number 55
#  Current loss 0.4247131943702698
#
# Epoch number 55
#  Current loss 0.3616805076599121
#
# Epoch number 55
#  Current loss 0.45451924204826355
#
# Epoch number 55
#  Current loss 0.4883408546447754
#
# Epoch number 55
#  Current loss 0.29915717244148254
#
# Epoch number 55
#  Current loss 0.3511037528514862
#
# Epoch number 55
#  Current loss 0.3890717923641205
#
# Epoch number 55
#  Current loss 0.4158119857311249
#
# Epoch number 55
#  Current loss 0.3598805069923401
#
# Epoch number 55
#  Current loss 0.46542075276374817
#
# Epoch number 55
#  Current loss 0.4037357568740845
#
# Epoch number 56
#  Current loss 0.5207887887954712
#
# Epoch number 56
#  Current loss 0.40915578603744507
#
# Epoch number 56
#  Current loss 0.25754278898239136
#
# Epoch number 56
#  Current loss 0.5432906746864319
#
# Epoch number 56
#  Current loss 0.5257208347320557
#
# Epoch number 56
#  Current loss 0.4382249116897583
#
# Epoch number 56
#  Current loss 0.579583466053009
#
# Epoch number 56
#  Current loss 0.38644084334373474
#
# Epoch number 56
#  Current loss 0.5003938674926758
#
# Epoch number 56
#  Current loss 0.45679786801338196
#
# Epoch number 56
#  Current loss 0.49837565422058105
#
# Epoch number 56
#  Current loss 0.5113537311553955
#
# Epoch number 56
#  Current loss 0.4339028000831604
#
# Epoch number 57
#  Current loss 0.30304574966430664
#
# Epoch number 57
#  Current loss 0.5112955570220947
#
# Epoch number 57
#  Current loss 0.39837872982025146
#
# Epoch number 57
#  Current loss 0.3903922438621521
#
# Epoch number 57
#  Current loss 0.348774790763855
#
# Epoch number 57
#  Current loss 0.43514618277549744
#
# Epoch number 57
#  Current loss 0.3532460629940033
#
# Epoch number 57
#  Current loss 0.45669835805892944
#
# Epoch number 57
#  Current loss 0.4928894639015198
#
# Epoch number 57
#  Current loss 0.3826897144317627
#
# Epoch number 57
#  Current loss 0.38537487387657166
#
# Epoch number 57
#  Current loss 0.46888497471809387
#
# Epoch number 57
#  Current loss 0.377960205078125
#
# Epoch number 58
#  Current loss 0.2503030300140381
#
# Epoch number 58
#  Current loss 0.37900322675704956
#
# Epoch number 58
#  Current loss 0.46320199966430664
#
# Epoch number 58
#  Current loss 0.42072391510009766
#
# Epoch number 58
#  Current loss 0.4007430672645569
#
# Epoch number 58
#  Current loss 0.30745822191238403
#
# Epoch number 58
#  Current loss 0.4880775809288025
#
# Epoch number 58
#  Current loss 0.3873533606529236
#
# Epoch number 58
#  Current loss 0.45488616824150085
#
# Epoch number 58
#  Current loss 0.4405238628387451
#
# Epoch number 58
#  Current loss 0.3197128474712372
#
# Epoch number 58
#  Current loss 0.31913092732429504
#
# Epoch number 58
#  Current loss 0.3976284861564636
#
# Epoch number 59
#  Current loss 0.513422966003418
#
# Epoch number 59
#  Current loss 0.37816834449768066
#
# Epoch number 59
#  Current loss 0.5184627771377563
#
# Epoch number 59
#  Current loss 0.4042450785636902
#
# Epoch number 59
#  Current loss 0.48181718587875366
#
# Epoch number 59
#  Current loss 0.5054937601089478
#
# Epoch number 59
#  Current loss 0.40484344959259033
#
# Epoch number 59
#  Current loss 0.510553240776062
#
# Epoch number 59
#  Current loss 0.3846217691898346
#
# Epoch number 59
#  Current loss 0.4205274283885956
#
# Epoch number 59
#  Current loss 0.3597739040851593
#
# Epoch number 59
#  Current loss 0.3906196653842926
#
# Epoch number 59
#  Current loss 0.40116316080093384
#
# Epoch number 60
#  Current loss 0.5315767526626587
#
# Epoch number 60
#  Current loss 0.310070276260376
#
# Epoch number 60
#  Current loss 0.4716932773590088
#
# Epoch number 60
#  Current loss 0.3540445566177368
#
# Epoch number 60
#  Current loss 0.34398457407951355
#
# Epoch number 60
#  Current loss 0.3545868396759033
#
# Epoch number 60
#  Current loss 0.40403836965560913
#
# Epoch number 60
#  Current loss 0.448569655418396
#
# Epoch number 60
#  Current loss 0.3391571342945099
#
# Epoch number 60
#  Current loss 0.2965736985206604
#
# Epoch number 60
#  Current loss 0.4160803258419037
#
# Epoch number 60
#  Current loss 0.3363547623157501
#
# Epoch number 60
#  Current loss 0.3580126166343689
#
# Epoch number 61
#  Current loss 0.2972864508628845
#
# Epoch number 61
#  Current loss 0.40501275658607483
#
# Epoch number 61
#  Current loss 0.3297572731971741
#
# Epoch number 61
#  Current loss 0.4547579884529114
#
# Epoch number 61
#  Current loss 0.3212701082229614
#
# Epoch number 61
#  Current loss 0.3632168173789978
#
# Epoch number 61
#  Current loss 0.5135478973388672
#
# Epoch number 61
#  Current loss 0.5269544720649719
#
# Epoch number 61
#  Current loss 0.49112263321876526
#
# Epoch number 61
#  Current loss 0.3758388161659241
#
# Epoch number 61
#  Current loss 0.35379475355148315
#
# Epoch number 61
#  Current loss 0.37314552068710327
#
# Epoch number 61
#  Current loss 0.4164799451828003
#
# Epoch number 62
#  Current loss 0.3090062737464905
#
# Epoch number 62
#  Current loss 0.39123624563217163
#
# Epoch number 62
#  Current loss 0.45504963397979736
#
# Epoch number 62
#  Current loss 0.5112744569778442
#
# Epoch number 62
#  Current loss 0.48458319902420044
#
# Epoch number 62
#  Current loss 0.3757404088973999
#
# Epoch number 62
#  Current loss 0.3905504643917084
#
# Epoch number 62
#  Current loss 0.4709042012691498
#
# Epoch number 62
#  Current loss 0.3786728084087372
#
# Epoch number 62
#  Current loss 0.4295295476913452
#
# Epoch number 62
#  Current loss 0.5435145497322083
#
# Epoch number 62
#  Current loss 0.3769204914569855
#
# Epoch number 62
#  Current loss 0.298628032207489
#
# Epoch number 63
#  Current loss 0.26371845602989197
#
# Epoch number 63
#  Current loss 0.23923887312412262
#
# Epoch number 63
#  Current loss 0.40641456842422485
#
# Epoch number 63
#  Current loss 0.4540942311286926
#
# Epoch number 63
#  Current loss 0.4383834898471832
#
# Epoch number 63
#  Current loss 0.31203600764274597
#
# Epoch number 63
#  Current loss 0.2814684212207794
#
# Epoch number 63
#  Current loss 0.32399317622184753
#
# Epoch number 63
#  Current loss 0.42629626393318176
#
# Epoch number 63
#  Current loss 0.40157365798950195
#
# Epoch number 63
#  Current loss 0.2053273320198059
#
# Epoch number 63
#  Current loss 0.3921930193901062
#
# Epoch number 63
#  Current loss 0.3827575445175171
#
# Epoch number 64
#  Current loss 0.2975139021873474
#
# Epoch number 64
#  Current loss 0.3855910003185272
#
# Epoch number 64
#  Current loss 0.4677669405937195
#
# Epoch number 64
#  Current loss 0.3183228373527527
#
# Epoch number 64
#  Current loss 0.37912970781326294
#
# Epoch number 64
#  Current loss 0.2984248399734497
#
# Epoch number 64
#  Current loss 0.3413587510585785
#
# Epoch number 64
#  Current loss 0.3132427930831909
#
# Epoch number 64
#  Current loss 0.2500406503677368
#
# Epoch number 64
#  Current loss 0.3574221134185791
#
# Epoch number 64
#  Current loss 0.5291973948478699
#
# Epoch number 64
#  Current loss 0.22492673993110657
#
# Epoch number 64
#  Current loss 0.3185582160949707
#
# Epoch number 65
#  Current loss 0.3756828308105469
#
# Epoch number 65
#  Current loss 0.3946664333343506
#
# Epoch number 65
#  Current loss 0.39332515001296997
#
# Epoch number 65
#  Current loss 0.4030393362045288
#
# Epoch number 65
#  Current loss 0.42232054471969604
#
# Epoch number 65
#  Current loss 0.4557347893714905
#
# Epoch number 65
#  Current loss 0.2669687271118164
#
# Epoch number 65
#  Current loss 0.5931209921836853
#
# Epoch number 65
#  Current loss 0.520767092704773
#
# Epoch number 65
#  Current loss 0.28428828716278076
#
# Epoch number 65
#  Current loss 0.39923688769340515
#
# Epoch number 65
#  Current loss 0.36696457862854004
#
# Epoch number 65
#  Current loss 0.49667295813560486
#
# Epoch number 66
#  Current loss 0.3662117123603821
#
# Epoch number 66
#  Current loss 0.22928142547607422
#
# Epoch number 66
#  Current loss 0.35266703367233276
#
# Epoch number 66
#  Current loss 0.28660717606544495
#
# Epoch number 66
#  Current loss 0.42746782302856445
#
# Epoch number 66
#  Current loss 0.24596834182739258
#
# Epoch number 66
#  Current loss 0.5693517923355103
#
# Epoch number 66
#  Current loss 0.42797207832336426
#
# Epoch number 66
#  Current loss 0.36630940437316895
#
# Epoch number 66
#  Current loss 0.3912608027458191
#
# Epoch number 66
#  Current loss 0.27151182293891907
#
# Epoch number 66
#  Current loss 0.3090454339981079
#
# Epoch number 66
#  Current loss 0.2669869661331177
#
# Epoch number 67
#  Current loss 0.39484700560569763
#
# Epoch number 67
#  Current loss 0.28606465458869934
#
# Epoch number 67
#  Current loss 0.268363893032074
#
# Epoch number 67
#  Current loss 0.38829803466796875
#
# Epoch number 67
#  Current loss 0.4304046630859375
#
# Epoch number 67
#  Current loss 0.3924851417541504
#
# Epoch number 67
#  Current loss 0.34542620182037354
#
# Epoch number 67
#  Current loss 0.4176858365535736
#
# Epoch number 67
#  Current loss 0.3975628614425659
#
# Epoch number 67
#  Current loss 0.3986847698688507
#
# Epoch number 67
#  Current loss 0.36389368772506714
#
# Epoch number 67
#  Current loss 0.3473142087459564
#
# Epoch number 67
#  Current loss 0.3267494738101959
#
# Epoch number 68
#  Current loss 0.49815988540649414
#
# Epoch number 68
#  Current loss 0.4514526128768921
#
# Epoch number 68
#  Current loss 0.4769921898841858
#
# Epoch number 68
#  Current loss 0.30056196451187134
#
# Epoch number 68
#  Current loss 0.32483619451522827
#
# Epoch number 68
#  Current loss 0.3060908615589142
#
# Epoch number 68
#  Current loss 0.3915971517562866
#
# Epoch number 68
#  Current loss 0.42757025361061096
#
# Epoch number 68
#  Current loss 0.3605286180973053
#
# Epoch number 68
#  Current loss 0.38717198371887207
#
# Epoch number 68
#  Current loss 0.4352043867111206
#
# Epoch number 68
#  Current loss 0.634721040725708
#
# Epoch number 68
#  Current loss 0.3376809358596802
#
# Epoch number 69
#  Current loss 0.2767276167869568
#
# Epoch number 69
#  Current loss 0.26423388719558716
#
# Epoch number 69
#  Current loss 0.3827078342437744
#
# Epoch number 69
#  Current loss 0.3541949689388275
#
# Epoch number 69
#  Current loss 0.28356286883354187
#
# Epoch number 69
#  Current loss 0.27240288257598877
#
# Epoch number 69
#  Current loss 0.3440451920032501
#
# Epoch number 69
#  Current loss 0.3985547125339508
#
# Epoch number 69
#  Current loss 0.38806843757629395
#
# Epoch number 69
#  Current loss 0.2790009379386902
#
# Epoch number 69
#  Current loss 0.4894087314605713
#
# Epoch number 69
#  Current loss 0.3269971013069153
#
# Epoch number 69
#  Current loss 0.474242627620697
#
# Epoch number 70
#  Current loss 0.4150875210762024
#
# Epoch number 70
#  Current loss 0.24057796597480774
#
# Epoch number 70
#  Current loss 0.3546593189239502
#
# Epoch number 70
#  Current loss 0.43624651432037354
#
# Epoch number 70
#  Current loss 0.3171929717063904
#
# Epoch number 70
#  Current loss 0.4186047315597534
#
# Epoch number 70
#  Current loss 0.3155512809753418
#
# Epoch number 70
#  Current loss 0.3759216368198395
#
# Epoch number 70
#  Current loss 0.5603336095809937
#
# Epoch number 70
#  Current loss 0.34046387672424316
#
# Epoch number 70
#  Current loss 0.3896169066429138
#
# Epoch number 70
#  Current loss 0.278990238904953
#
# Epoch number 70
#  Current loss 0.2677995562553406
#
# Epoch number 71
#  Current loss 0.3995697498321533
#
# Epoch number 71
#  Current loss 0.3995135426521301
#
# Epoch number 71
#  Current loss 0.3144817352294922
#
# Epoch number 71
#  Current loss 0.36384713649749756
#
# Epoch number 71
#  Current loss 0.3687884211540222
#
# Epoch number 71
#  Current loss 0.34167730808258057
#
# Epoch number 71
#  Current loss 0.48161518573760986
#
# Epoch number 71
#  Current loss 0.28526437282562256
#
# Epoch number 71
#  Current loss 0.2373468428850174
#
# Epoch number 71
#  Current loss 0.360603392124176
#
# Epoch number 71
#  Current loss 0.3942551016807556
#
# Epoch number 71
#  Current loss 0.2831973731517792
#
# Epoch number 71
#  Current loss 0.46171820163726807
#
# Epoch number 72
#  Current loss 0.2778800129890442
#
# Epoch number 72
#  Current loss 0.36503294110298157
#
# Epoch number 72
#  Current loss 0.26249730587005615
#
# Epoch number 72
#  Current loss 0.35408249497413635
#
# Epoch number 72
#  Current loss 0.3826064169406891
#
# Epoch number 72
#  Current loss 0.38421618938446045
#
# Epoch number 72
#  Current loss 0.3127233386039734
#
# Epoch number 72
#  Current loss 0.2278010994195938
#
# Epoch number 72
#  Current loss 0.31371384859085083
#
# Epoch number 72
#  Current loss 0.43720293045043945
#
# Epoch number 72
#  Current loss 0.4732370376586914
#
# Epoch number 72
#  Current loss 0.32901304960250854
#
# Epoch number 72
#  Current loss 0.41823524236679077
#
# Epoch number 73
#  Current loss 0.22605502605438232
#
# Epoch number 73
#  Current loss 0.429689884185791
#
# Epoch number 73
#  Current loss 0.3038637340068817
#
# Epoch number 73
#  Current loss 0.3835080862045288
#
# Epoch number 73
#  Current loss 0.2141943871974945
#
# Epoch number 73
#  Current loss 0.35934656858444214
#
# Epoch number 73
#  Current loss 0.4662431478500366
#
# Epoch number 73
#  Current loss 0.4128410220146179
#
# Epoch number 73
#  Current loss 0.4164695143699646
#
# Epoch number 73
#  Current loss 0.2934897541999817
#
# Epoch number 73
# ...
#
# Epoch number 75
#  Current loss 0.37917351722717285
#
# Epoch number 75
#  Current loss 0.3031150698661804
#
# Epoch number 75
#  Current loss 0.297281950712204
#
# Epoch number 75
#  Current loss 0.4469343423843384
#
# Epoch number 75
#  Current loss 0.3418717384338379
#
# Epoch number 76
#  Current loss 0.36401090025901794
#
# Epoch number 76
#  Current loss 0.38690900802612305
#
# Epoch number 76
#  Current loss 0.2687407433986664
#
# Epoch number 76
#  Current loss 0.3835483193397522
#
# Epoch number 76
#  Current loss 0.3107566237449646
#
# Epoch number 76
#  Current loss 0.3280569314956665
#
# Epoch number 76
#  Current loss 0.28038495779037476
#
# Epoch number 76
#  Current loss 0.24905534088611603
#
# Epoch number 76
#  Current loss 0.3973303437232971
#
# Epoch number 76
#  Current loss 0.23282331228256226
#
# Epoch number 76
#  Current loss 0.19631940126419067
#
# Epoch number 76
#  Current loss 0.3132789433002472
#
# Epoch number 76
#  Current loss 0.5106282830238342
#
# Epoch number 77
#  Current loss 0.2247341275215149
#
# Epoch number 77
#  Current loss 0.30517321825027466
#
# Epoch number 77
#  Current loss 0.48886746168136597
#
# Epoch number 77
#  Current loss 0.48087048530578613
#
# Epoch number 77
#  Current loss 0.318337619304657
#
# Epoch number 77
#  Current loss 0.2847869396209717
#
# Epoch number 77
#  Current loss 0.31234651803970337
#
# Epoch number 77
#  Current loss 0.3275478482246399
#
# Epoch number 77
#  Current loss 0.25843942165374756
#
# Epoch number 77
#  Current loss 0.3249116539955139
#
# Epoch number 77
#  Current loss 0.16258080303668976
#
# Epoch number 77
#  Current loss 0.3971646726131439
#
# Epoch number 77
#  Current loss 0.44046497344970703
#
# Epoch number 78
#  Current loss 0.41778242588043213
#
# Epoch number 78
#  Current loss 0.4192396402359009
#
# Epoch number 78
#  Current loss 0.28776609897613525
#
# Epoch number 78
#  Current loss 0.3283994793891907
#
# Epoch number 78
#  Current loss 0.3081342577934265
#
# Epoch number 78
#  Current loss 0.4158346652984619
#
# Epoch number 78
#  Current loss 0.36036235094070435
#
# Epoch number 78
#  Current loss 0.4012395441532135
#
# Epoch number 78
#  Current loss 0.1892993152141571
#
# Epoch number 78
#  Current loss 0.2634115517139435
#
# Epoch number 78
#  Current loss 0.1863017976284027
#
# Epoch number 78
#  Current loss 0.26562607288360596
#
# Epoch number 78
#  Current loss 0.3346816897392273
#
# Epoch number 79
#  Current loss 0.3084394037723541
#
# Epoch number 79
#  Current loss 0.29975712299346924
#
# Epoch number 79
#  Current loss 0.39273494482040405
#
# Epoch number 79
#  Current loss 0.18147660791873932
#
# Epoch number 79
#  Current loss 0.32869410514831543
#
# Epoch number 79
#  Current loss 0.27956315875053406
#
# Epoch number 79
#  Current loss 0.4261096715927124
#
# Epoch number 79
#  Current loss 0.2199295163154602
#
# Epoch number 79
#  Current loss 0.3312370479106903
#
# Epoch number 79
#  Current loss 0.23247167468070984
#
# Epoch number 79
#  Current loss 0.21179720759391785
#
# Epoch number 79
#  Current loss 0.3409841060638428
#
# Epoch number 79
#  Current loss 0.281444251537323
#
# Epoch number 80
#  Current loss 0.3071405291557312
#
# Epoch number 80
#  Current loss 0.24543803930282593
#
# Epoch number 80
#  Current loss 0.39806514978408813
#
# Epoch number 80
#  Current loss 0.13956519961357117
#
# Epoch number 80
#  Current loss 0.28631219267845154
#
# Epoch number 80
#  Current loss 0.3400241434574127
#
# Epoch number 80
#  Current loss 0.3393474519252777
#
# Epoch number 80
#  Current loss 0.3678133487701416
#
# Epoch number 80
#  Current loss 0.3387039303779602
#
# Epoch number 80
#  Current loss 0.24313417077064514
#
# Epoch number 80
#  Current loss 0.27563512325286865
#
# Epoch number 80
#  Current loss 0.3841845393180847
#
# Epoch number 80
#  Current loss 0.3217669129371643
#
# Epoch number 81
#  Current loss 0.1690230667591095
#
# Epoch number 81
#  Current loss 0.4718893766403198
#
# Epoch number 81
#  Current loss 0.324233740568161
#
# Epoch number 81
#  Current loss 0.21558277308940887
#
# Epoch number 81
#  Current loss 0.28514358401298523
#
# Epoch number 81
#  Current loss 0.32718291878700256
#
# Epoch number 81
#  Current loss 0.2708393931388855
#
# Epoch number 81
#  Current loss 0.35872310400009155
#
# Epoch number 81
#  Current loss 0.3300512731075287
#
# Epoch number 81
#  Current loss 0.356300413608551
#
# Epoch number 81
#  Current loss 0.39617273211479187
#
# Epoch number 81
#  Current loss 0.29062142968177795
#
# Epoch number 81
#  Current loss 0.3358275592327118
#
# Epoch number 82
#  Current loss 0.3955240845680237
#
# Epoch number 82
#  Current loss 0.32641685009002686
#
# Epoch number 82
#  Current loss 0.3774339258670807
#
# Epoch number 82
#  Current loss 0.2456846982240677
#
# Epoch number 82
#  Current loss 0.22225472331047058
#
# Epoch number 82
#  Current loss 0.48858803510665894
#
# Epoch number 82
#  Current loss 0.44690564274787903
#
# Epoch number 82
#  Current loss 0.3740713894367218
#
# Epoch number 82
#  Current loss 0.2518377900123596
#
# Epoch number 82
#  Current loss 0.3033795654773712
#
# Epoch number 82
#  Current loss 0.4443826377391815
#
# Epoch number 82
#  Current loss 0.39411014318466187
#
# Epoch number 82
#  Current loss 0.3451884984970093
#
# Epoch number 83
#  Current loss 0.19295066595077515
#
# Epoch number 83
#  Current loss 0.3412398397922516
#
# Epoch number 83
#  Current loss 0.31390446424484253
#
# Epoch number 83
#  Current loss 0.31209272146224976
#
# Epoch number 83
#  Current loss 0.3098578453063965
#
# Epoch number 83
#  Current loss 0.5682591199874878
#
# Epoch number 83
#  Current loss 0.23560693860054016
#
# Epoch number 83
#  Current loss 0.315284788608551
#
# Epoch number 83
#  Current loss 0.31611543893814087
#
# Epoch number 83
#  Current loss 0.2652347981929779
#
# Epoch number 83
#  Current loss 0.2286464273929596
#
# Epoch number 83
#  Current loss 0.2767268121242523
#
# Epoch number 83
#  Current loss 0.33593687415122986
#
# Epoch number 84
#  Current loss 0.2930558919906616
#
# Epoch number 84
#  Current loss 0.3947567939758301
#
# Epoch number 84
#  Current loss 0.21333299577236176
#
# Epoch number 84
#  Current loss 0.24613209068775177
#
# Epoch number 84
#  Current loss 0.18057683110237122
#
# Epoch number 84
#  Current loss 0.24365615844726562
#
# Epoch number 84
#  Current loss 0.37744519114494324
#
# Epoch number 84
#  Current loss 0.2114103138446808
#
# Epoch number 84
#  Current loss 0.3615325689315796
#
# Epoch number 84
#  Current loss 0.3358580768108368
#
# Epoch number 84
#  Current loss 0.4028998911380768
#
# Epoch number 84
#  Current loss 0.3654966950416565
#
# Epoch number 84
#  Current loss 0.44172656536102295
#
# Epoch number 85
#  Current loss 0.19495445489883423
#
# Epoch number 85
#  Current loss 0.2948894798755646
#
# Epoch number 85
#  Current loss 0.31318143010139465
#
# Epoch number 85
#  Current loss 0.41214075684547424
#
# Epoch number 85
#  Current loss 0.2909141778945923
#
# Epoch number 85
#  Current loss 0.2266397774219513
#
# Epoch number 85
#  Current loss 0.18723727762699127
#
# Epoch number 85
#  Current loss 0.37724095582962036
#
# Epoch number 85
#  Current loss 0.2959052622318268
#
# Epoch number 85
#  Current loss 0.38071808218955994
#
# Epoch number 85
#  Current loss 0.3014817535877228
#
# Epoch number 85
#  Current loss 0.28869134187698364
#
# Epoch number 85
#  Current loss 0.4194585084915161
#
# Epoch number 86
#  Current loss 0.46128588914871216
#
# Epoch number 86
#  Current loss 0.3802516460418701
#
# Epoch number 86
#  Current loss 0.2505838871002197
#
# Epoch number 86
#  Current loss 0.3619821071624756
#
# Epoch number 86
#  Current loss 0.16435077786445618
#
# Epoch number 86
#  Current loss 0.2687169015407562
#
# Epoch number 86
#  Current loss 0.19766953587532043
#
# Epoch number 86
#  Current loss 0.21458086371421814
#
# Epoch number 86
#  Current loss 0.19491448998451233
#
# Epoch number 86
#  Current loss 0.18735982477664948
#
# Epoch number 86
#  Current loss 0.3217628002166748
#
# Epoch number 86
#  Current loss 0.3254411220550537
#
# Epoch number 86
#  Current loss 0.23105040192604065
#
# Epoch number 87
#  Current loss 0.38599854707717896
#
# Epoch number 87
#  Current loss 0.3220531940460205
#
# Epoch number 87
#  Current loss 0.3080504536628723
#
# Epoch number 87
#  Current loss 0.3516078293323517
#
# Epoch number 87
#  Current loss 0.24056842923164368
#
# Epoch number 87
#  Current loss 0.27216535806655884
#
# Epoch number 87
#  Current loss 0.28845614194869995
#
# Epoch number 87
#  Current loss 0.4542112350463867
#
# Epoch number 87
#  Current loss 0.16901347041130066
#
# Epoch number 87
#  Current loss 0.34291568398475647
#
# Epoch number 87
#  Current loss 0.2702926993370056
#
# Epoch number 87
#  Current loss 0.3009900152683258
#
# Epoch number 87
#  Current loss 0.46716371178627014
#
# Epoch number 88
#  Current loss 0.2548408806324005
#
# Epoch number 88
#  Current loss 0.24892008304595947
#
# Epoch number 88
#  Current loss 0.331448495388031
#
# Epoch number 88
#  Current loss 0.3246600031852722
#
# Epoch number 88
#  Current loss 0.40752023458480835
#
# Epoch number 88
#  Current loss 0.223740354180336
#
# Epoch number 88
#  Current loss 0.209812194108963
#
# Epoch number 88
#  Current loss 0.2465103566646576
#
# Epoch number 88
#  Current loss 0.3875560164451599
#
# Epoch number 88
#  Current loss 0.2980097830295563
#
# Epoch number 88
#  Current loss 0.23459824919700623
#
# Epoch number 88
#  Current loss 0.24010145664215088
#
# Epoch number 88
#  Current loss 0.2882724404335022
#
# Epoch number 89
#  Current loss 0.2876790761947632
#
# Epoch number 89
#  Current loss 0.3346419334411621
#
# Epoch number 89
#  Current loss 0.2585446834564209
#
# Epoch number 89
#  Current loss 0.4560092091560364
#
# Epoch number 89
#  Current loss 0.2675324082374573
#
# Epoch number 89
#  Current loss 0.330763578414917
#
# Epoch number 89
#  Current loss 0.28156277537345886
#
# Epoch number 89
#  Current loss 0.33174818754196167
#
# Epoch number 89
#  Current loss 0.25248855352401733
#
# Epoch number 89
#  Current loss 0.2771601676940918
#
# Epoch number 89
#  Current loss 0.36201417446136475
#
# Epoch number 89
#  Current loss 0.2626335024833679
#
# Epoch number 89
#  Current loss 0.27489691972732544
#
# Epoch number 90
#  Current loss 0.32797902822494507
#
# Epoch number 90
#  Current loss 0.3528919219970703
#
# Epoch number 90
#  Current loss 0.2962554395198822
#
# Epoch number 90
#  Current loss 0.30066996812820435
#
# Epoch number 90
#  Current loss 0.3460659980773926
#
# Epoch number 90
#  Current loss 0.28995198011398315
#
# Epoch number 90
#  Current loss 0.1947384476661682
#
# Epoch number 90
#  Current loss 0.2789946496486664
#
# Epoch number 90
#  Current loss 0.20136144757270813
#
# Epoch number 90
#  Current loss 0.1848313808441162
#
# Epoch number 90
#  Current loss 0.3013373613357544
#
# Epoch number 90
#  Current loss 0.25586560368537903
#
# Epoch number 90
#  Current loss 0.40146195888519287
#
# Epoch number 91
#  Current loss 0.2589414417743683
#
# Epoch number 91
#  Current loss 0.344186007976532
#
# Epoch number 91
#  Current loss 0.41902631521224976
#
# Epoch number 91
#  Current loss 0.181463360786438
#
# Epoch number 91
#  Current loss 0.3504554033279419
#
# Epoch number 91
#  Current loss 0.26563403010368347
#
# Epoch number 91
#  Current loss 0.38915184140205383
#
# Epoch number 91
#  Current loss 0.2933242619037628
#
# Epoch number 91
#  Current loss 0.25790899991989136
#
# Epoch number 91
#  Current loss 0.2907993793487549
#
# Epoch number 91
#  Current loss 0.30890628695487976
#
# Epoch number 91
#  Current loss 0.32378503680229187
#
# Epoch number 91
#  Current loss 0.40048062801361084
#
# Epoch number 92
#  Current loss 0.3331674635410309
#
# Epoch number 92
#  Current loss 0.4675155580043793
#
# Epoch number 92
#  Current loss 0.2638196349143982
#
# Epoch number 92
#  Current loss 0.25022998452186584
#
# Epoch number 92
#  Current loss 0.27422982454299927
#
# Epoch number 92
#  Current loss 0.1908915936946869
#
# Epoch number 92
#  Current loss 0.35596469044685364
#
# Epoch number 92
#  Current loss 0.29083961248397827
#
# Epoch number 92
#  Current loss 0.31843096017837524
#
# Epoch number 92
#  Current loss 0.22416117787361145
#
# Epoch number 92
#  Current loss 0.2709044814109802
#
# Epoch number 92
#  Current loss 0.21987506747245789
#
# Epoch number 92
#  Current loss 0.33383631706237793
#
# Epoch number 93
#  Current loss 0.2900804877281189
#
# Epoch number 93
#  Current loss 0.2667444050312042
#
# Epoch number 93
#  Current loss 0.3365711271762848
#
# Epoch number 93
#  Current loss 0.42204222083091736
#
# Epoch number 93
#  Current loss 0.28840214014053345
#
# Epoch number 93
#  Current loss 0.2634041905403137
#
# Epoch number 93
#  Current loss 0.19714124500751495
#
# Epoch number 93
#  Current loss 0.24267908930778503
#
# Epoch number 93
#  Current loss 0.42414504289627075
#
# Epoch number 93
#  Current loss 0.2764817774295807
#
# Epoch number 93
#  Current loss 0.32801681756973267
#
# Epoch number 93
#  Current loss 0.35568755865097046
#
# Epoch number 93
#  Current loss 0.3534849286079407
#
# Epoch number 94
#  Current loss 0.28925544023513794
#
# Epoch number 94
#  Current loss 0.21525835990905762
#
# Epoch number 94
#  Current loss 0.22611494362354279
#
# Epoch number 94
#  Current loss 0.26188093423843384
#
# Epoch number 94
#  Current loss 0.370073139667511
#
# Epoch number 94
#  Current loss 0.28321051597595215
#
# Epoch number 94
#  Current loss 0.15821629762649536
#
# Epoch number 94
#  Current loss 0.28388512134552
#
# Epoch number 94
#  Current loss 0.1531374156475067
#
# Epoch number 94
#  Current loss 0.21537572145462036
#
# Epoch number 94
#  Current loss 0.24281451106071472
#
# Epoch number 94
#  Current loss 0.28652217984199524
#
# Epoch number 94
#  Current loss 0.21603193879127502
#
# Epoch number 95
#  Current loss 0.2816956639289856
#
# Epoch number 95
#  Current loss 0.34919053316116333
#
# Epoch number 95
#  Current loss 0.32064178586006165
#
# Epoch number 95
#  Current loss 0.30965298414230347
#
# Epoch number 95
#  Current loss 0.2862084209918976
#
# Epoch number 95
#  Current loss 0.28051117062568665
#
# Epoch number 95
#  Current loss 0.25697383284568787
#
# Epoch number 95
#  Current loss 0.1813773214817047
#
# Epoch number 95
#  Current loss 0.2778562009334564
#
# Epoch number 95
#  Current loss 0.2708381414413452
#
# Epoch number 95
#  Current loss 0.25976821780204773
#
# Epoch number 95
#  Current loss 0.3772527575492859
#
# Epoch number 95
#  Current loss 0.23639532923698425
#
# Epoch number 96
#  Current loss 0.36724185943603516
#
# Epoch number 96
#  Current loss 0.3168244957923889
#
# Epoch number 96
#  Current loss 0.4031394422054291
#
# Epoch number 96
#  Current loss 0.31106775999069214
#
# Epoch number 96
#  Current loss 0.24224090576171875
#
# Epoch number 96
#  Current loss 0.33719831705093384
#
# Epoch number 96
#  Current loss 0.2461196780204773
#
# Epoch number 96
#  Current loss 0.14212945103645325
#
# Epoch number 96
#  Current loss 0.4693260192871094
#
# Epoch number 96
#  Current loss 0.2722119390964508
#
# Epoch number 96
#  Current loss 0.2990449070930481
#
# Epoch number 96
#  Current loss 0.22036337852478027
#
# Epoch number 96
#  Current loss 0.30094295740127563
#
# Epoch number 97
#  Current loss 0.21871408820152283
#
# Epoch number 97
#  Current loss 0.18232330679893494
#
# Epoch number 97
#  Current loss 0.3484630584716797
#
# Epoch number 97
#  Current loss 0.3171967566013336
#
# Epoch number 97
#  Current loss 0.36227256059646606
#
# Epoch number 97
#  Current loss 0.30246320366859436
#
# Epoch number 97
#  Current loss 0.34191784262657166
#
# Epoch number 97
#  Current loss 0.2265702486038208
#
# Epoch number 97
#  Current loss 0.28770095109939575
#
# Epoch number 97
#  Current loss 0.282692551612854
#
# Epoch number 97
#  Current loss 0.25106537342071533
#
# Epoch number 97
#  Current loss 0.26279130578041077
#
# Epoch number 97
#  Current loss 0.26088258624076843
#
# Epoch number 98
#  Current loss 0.23984788358211517
#
# Epoch number 98
#  Current loss 0.34736090898513794
#
# Epoch number 98
#  Current loss 0.26189297437667847
#
# Epoch number 98
#  Current loss 0.24632377922534943
#
# Epoch number 98
#  Current loss 0.2739197313785553
#
# Epoch number 98
#  Current loss 0.3419352173805237
#
# Epoch number 98
#  Current loss 0.23402811586856842
#
# Epoch number 98
#  Current loss 0.28678733110427856
#
# Epoch number 98
#  Current loss 0.226624995470047
#
# Epoch number 98
#  Current loss 0.32369449734687805
#
# Epoch number 98
#  Current loss 0.3363707661628723
#
# Epoch number 98
#  Current loss 0.2686321437358856
#
# Epoch number 98
#  Current loss 0.3053478002548218
#
# Epoch number 99
#  Current loss 0.2626001238822937
#
# Epoch number 99
#  Current loss 0.4228343367576599
#
# Epoch number 99
#  Current loss 0.3787713348865509
#
# Epoch number 99
#  Current loss 0.2847632169723511
#
# Epoch number 99
#  Current loss 0.35070788860321045
#
# Epoch number 99
#  Current loss 0.21653880178928375
#
# Epoch number 99
#  Current loss 0.2708815932273865
#
# Epoch number 99
#  Current loss 0.24689528346061707
#
# Epoch number 99
#  Current loss 0.295528769493103
#
# Epoch number 99
#  Current loss 0.2485477775335312
#
# Epoch number 99
#  Current loss 0.24939239025115967
#
# Epoch number 99
#  Current loss 0.2784350514411926
#
# Epoch number 99
#  Current loss 0.28500428795814514

# %%
folder_dataset_test = datasets.ImageFolder(root="D:\Desktop\FACES_PGM_TEST/")
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transformation)
test_dataloader = DataLoader(siamese_dataset, num_workers=0, batch_size=1, shuffle=True)

dataiter = iter(test_dataloader)
x0, _, _ = next(dataiter)

for i in range(10):
    _, x1, label2 = next(dataiter)

    concatenated = torch.cat((x0, x1), 0)
    
    output1, output2 = net(x0.cuda(), x1.cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {euclidean_distance.item():.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Locate the test dataset and load it into the SiameseNetworkDataset
# ----> 2 folder_dataset_test = datasets.ImageFolder(root="D:\Desktop\FACES_PGM_TEST/")
#       3 siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
#       4                                         transform=transformation)
#       5 test_dataloader = DataLoader(siamese_dataset, num_workers=0, batch_size=1, shuffle=True)
#
# NameError: name 'datasets' is not defined

# %%
torch.save(net.state_dict(), 'siamese_model_TRAINED_ORIGINALS.pth')
