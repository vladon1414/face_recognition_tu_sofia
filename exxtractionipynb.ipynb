# %%
import os
import cv2
import pandas as pd
import numpy as np
import pytesseract
from mtcnn import MTCNN


# Load CSV
csv_path = "updated_data.csv"  # Replace with your updated CSV file path
df = pd.read_csv(csv_path)


# Limit to first 50 persons
# df_subset = df.iloc[234:255]
df_subset = df.head()

# Create output directory
output_dir = "extracted_id_faces"

# Initialize MTCNN detector
detector = MTCNN()

# Function for multi-angle detection
def detect_best_face(image):
    angles = [0, 90, 180, 270]
    best_result = None
    best_confidence = 0
    best_angle = 0
    best_img = image

    for angle in angles:
        if angle == 0:
            rotated_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        elif angle == 90:
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_90_CLOCKWISE)
        elif angle == 180:
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_180)
        else:  # 270
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_90_COUNTERCLOCKWISE)

        faces = detector.detect_faces(rotated_img)
        if faces and faces[0]['confidence'] > best_confidence:
            best_confidence = faces[0]['confidence']
            best_result = faces[0]
            best_angle = angle
            best_img = rotated_img

    return best_result, best_angle, best_img, best_confidence  # Added best_confidence to return

# Process each ID image
for index, row in df_subset.iterrows():
    id_image_path = row['ID_IMAGE']
    person_id = row['ID']

    # Load image
    img = cv2.imread(id_image_path)
    if img is None:
        print(f"Error loading image: {id_image_path}")
        continue

    # Detect best face across all angles
    best_face, best_angle, img_to_annotate, best_confidence = detect_best_face(img)  # Updated to receive best_confidence
    print(f"Best detection for person {person_id} at {best_angle} degrees with confidence {best_confidence if best_face else 0}")

    # Annotate the image
    if best_face:
        x, y, w, h = best_face['box']
        x, y = max(0, x), max(0, y)

        # Draw bounding box (green)
        cv2.rectangle(img_to_annotate, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Draw landmarks (red dots)
        landmarks = best_face['keypoints']
        for key, point in landmarks.items():
            cv2.circle(img_to_annotate, point, 3, (0, 0, 255), -1)

        # Draw eye line (blue)
        left_eye = landmarks['left_eye']
        right_eye = landmarks['right_eye']
        cv2.line(img_to_annotate, left_eye, right_eye, (255, 0, 0), 2)
    else:
        # No face detected, draw a placeholder
        height, width = img_to_annotate.shape[:2]
        center = (width // 2, height // 2)
        cv2.rectangle(img_to_annotate, (center[0] - 50, center[1] - 50), (center[0] + 50, center[1] + 50), (0, 0, 255), 2, cv2.LINE_4)
        cv2.putText(img_to_annotate, "No Face Detected", (center[0] - 40, center[1] - 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # Convert back to BGR for display and saving
    img_annotated = cv2.cvtColor(img_to_annotate, cv2.COLOR_RGB2BGR)

    # Display the annotated image
    # cv2.imshow(f"Person {person_id} - Press any key to continue", img_annotated)
    # print(f"Displaying person {person_id}. Check the bounding box, landmarks, and eye line.")

    # Save the annotated image
    output_path = os.path.join(output_dir, f"person_{person_id}_annotated.jpg")
    cv2.imwrite(output_path, img_annotated)
    print(f"Saved annotated image to {output_path}")

    # Wait for user input to continue
    print("Press any key to continue to the next image (or 'q' to quit)...")
    key = cv2.waitKey(0)
    if key & 0xFF == ord('q'):
        print("Quitting early.")
        break

# Close all windows
cv2.destroyAllWindows()
print("Visualization complete!")
# Out:
# Best detection for person 235 at 0 degrees with confidence 0.8145400285720825
# Saved annotated image to extracted_id_faces\person_235_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 236 at 0 degrees with confidence 0.9989098310470581
# Saved annotated image to extracted_id_faces\person_236_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 237 at 0 degrees with confidence 0.9982855916023254
# Saved annotated image to extracted_id_faces\person_237_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 238 at 0 degrees with confidence 0
# Saved annotated image to extracted_id_faces\person_238_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 239 at 0 degrees with confidence 0
# Saved annotated image to extracted_id_faces\person_239_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 240 at 270 degrees with confidence 0.9861196279525757
# Saved annotated image to extracted_id_faces\person_240_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 241 at 270 degrees with confidence 0.974728524684906
# Saved annotated image to extracted_id_faces\person_241_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 242 at 270 degrees with confidence 0.998813271522522
# Saved annotated image to extracted_id_faces\person_242_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 243 at 270 degrees with confidence 0.9969033598899841
# Saved annotated image to extracted_id_faces\person_243_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 244 at 270 degrees with confidence 0.9989443421363831
# Saved annotated image to extracted_id_faces\person_244_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 245 at 270 degrees with confidence 0.9996782541275024
# Saved annotated image to extracted_id_faces\person_245_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 246 at 270 degrees with confidence 0.9998601675033569
# Saved annotated image to extracted_id_faces\person_246_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 247 at 270 degrees with confidence 0.9982398748397827
# Saved annotated image to extracted_id_faces\person_247_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 248 at 270 degrees with confidence 0.996209979057312
# Saved annotated image to extracted_id_faces\person_248_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 249 at 270 degrees with confidence 0.9992075562477112
# Saved annotated image to extracted_id_faces\person_249_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 250 at 90 degrees with confidence 0.9997047781944275
# Saved annotated image to extracted_id_faces\person_250_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 251 at 0 degrees with confidence 0.9932297468185425
# Saved annotated image to extracted_id_faces\person_251_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 252 at 0 degrees with confidence 0.9956670999526978
# Saved annotated image to extracted_id_faces\person_252_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 253 at 90 degrees with confidence 0.9998061060905457
# Saved annotated image to extracted_id_faces\person_253_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 254 at 0 degrees with confidence 0.9995200634002686
# Saved annotated image to extracted_id_faces\person_254_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Best detection for person 255 at 0 degrees with confidence 0.9994702935218811
# Saved annotated image to extracted_id_faces\person_255_annotated.jpg
# Press any key to continue to the next image (or 'q' to quit)...
# Visualization complete!

# %%
import os
import cv2
import pandas as pd
import numpy as np
from mtcnn import MTCNN

# Load CSV
csv_path = "updated_data.csv"  # Replace with your updated CSV file path
df = pd.read_csv(csv_path)

# Create output directories
output_dir = "extracted_id_faces"
log_dir = "extraction_logs"
for directory in [output_dir, log_dir]:
    if not os.path.exists(directory):
        os.makedirs(directory)

# Initialize MTCNN detector
detector = MTCNN()
print("MTCNN initialized with default parameters for version 1.0.0.")

# Preprocessing function (less aggressive)
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))  # Reduced clipLimit
    enhanced = clahe.apply(gray)
    denoised = cv2.GaussianBlur(enhanced, (3, 3), 0)  # Smaller kernel
    rgb_img = cv2.cvtColor(denoised, cv2.COLOR_GRAY2RGB)
    return rgb_img

# Function for multi-angle detection with improved validation
def detect_best_face(image):
    angles = [0, 180, 90, 270]
    best_result = None
    best_confidence = 0
    best_angle = 0
    best_img = image
    best_cropped_face = None

    for angle in angles:
        if angle == 0:
            rotated_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        elif angle == 90:
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_90_CLOCKWISE)
        elif angle == 180:
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_180)
        else:  # 270
            rotated_img = cv2.rotate(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), cv2.ROTATE_90_COUNTERCLOCKWISE)

        preprocessed_img = preprocess_image(rotated_img)
        faces = detector.detect_faces(
            preprocessed_img,
            # scale_factor=0.8,
            min_face_size=20,  # Adjusted to typical face size
            threshold_pnet=0.6,  # Stricter thresholds
            threshold_rnet=0.7,
            threshold_onet=0.8
        )
        if faces and faces[0]['confidence'] > best_confidence:
            best_confidence = faces[0]['confidence']
            best_result = faces[0]
            best_angle = angle
            best_img = rotated_img

            # Extract and validate bounding box
            x, y, w, h = best_result['box']
            x, y = max(0, x), max(0, y)
            # Ensure minimum size for cropping
            w, h = max(1, w), max(1, h)
            # Clip coordinates to image bounds
            x_end = min(best_img.shape[1], x + w)
            y_end = min(best_img.shape[0], y + h)
            x_start = max(0, x)
            y_start = max(0, y)

            # Crop the face
            if x_end > x_start and y_end > y_start:
                face_img = best_img[y_start:y_end, x_start:x_end]
                if face_img.size > 0:
                    best_cropped_face = cv2.resize(face_img, (224, 224))
                else:
                    with open(os.path.join(log_dir, "debug_log.txt"), 'a') as debug_log:
                        debug_log.write(f"Empty face_img for person {person_id} at angle {angle}: x={x_start}, y={y_start}, w={x_end-x_start}, h={y_end-y_start}, img_shape={best_img.shape}\n")
            else:
                with open(os.path.join(log_dir, "debug_log.txt"), 'a') as debug_log:
                    debug_log.write(f"Invalid crop dimensions for person {person_id} at angle {angle}: x_start={x_start}, y_start={y_start}, x_end={x_end}, y_end={y_end}, img_shape={best_img.shape}\n")

            if best_confidence > 0.9:
                break

    return best_result, best_angle, best_img, best_confidence, best_cropped_face

# Log file setup
log_file = os.path.join(log_dir, "extraction_log.txt")
with open(log_file, 'w') as log:
    log.write("Face Extraction Log\n")
    log.write("===================\n")

# Process all ID images
for index, row in df.iterrows():
    id_image_path = row['ID_IMAGE']
    person_id = row['ID']

    # Load image
    img = cv2.imread(id_image_path)
    if img is None:
        with open(log_file, 'a') as log:
            log.write(f"Error loading image for person {person_id}: {id_image_path}\n")
        continue

    # Detect best face across all angles
    best_face, best_angle, img_to_annotate, best_confidence, cropped_face = detect_best_face(img)
    with open(log_file, 'a') as log:
        log.write(f"Person {person_id}: Best detection at {best_angle} degrees with confidence {best_confidence if best_face else 0}\n")

    # Save the result
    if cropped_face is not None:
        output_path = os.path.join(output_dir, f"person_{person_id}_id_face.jpg")
        cv2.imwrite(output_path, cv2.cvtColor(cropped_face, cv2.COLOR_RGB2BGR))
        print(f"Extracted and saved face for person {person_id} at {output_path}")
    else:
        failed_path = os.path.join(output_dir, f"person_{person_id}_failed.jpg")
        cv2.imwrite(failed_path, img)
        print(f"No face detected for person {person_id}. Saved original image to {failed_path}")

print("Face extraction complete! Check extraction_log.txt and debug_log.txt for details.")
# Out:
# MTCNN initialized with default parameters for version 1.0.0.
# Extracted and saved face for person 1 at extracted_id_faces\person_1_id_face.jpg
# Extracted and saved face for person 2 at extracted_id_faces\person_2_id_face.jpg
# Extracted and saved face for person 3 at extracted_id_faces\person_3_id_face.jpg
# Extracted and saved face for person 4 at extracted_id_faces\person_4_id_face.jpg
# Extracted and saved face for person 5 at extracted_id_faces\person_5_id_face.jpg
# Extracted and saved face for person 6 at extracted_id_faces\person_6_id_face.jpg
# Extracted and saved face for person 7 at extracted_id_faces\person_7_id_face.jpg
# Extracted and saved face for person 8 at extracted_id_faces\person_8_id_face.jpg
# Extracted and saved face for person 9 at extracted_id_faces\person_9_id_face.jpg
# Extracted and saved face for person 10 at extracted_id_faces\person_10_id_face.jpg
# Extracted and saved face for person 11 at extracted_id_faces\person_11_id_face.jpg
# Extracted and saved face for person 12 at extracted_id_faces\person_12_id_face.jpg
# Extracted and saved face for person 13 at extracted_id_faces\person_13_id_face.jpg
# Extracted and saved face for person 14 at extracted_id_faces\person_14_id_face.jpg
# Extracted and saved face for person 15 at extracted_id_faces\person_15_id_face.jpg
# Extracted and saved face for person 16 at extracted_id_faces\person_16_id_face.jpg
# Extracted and saved face for person 17 at extracted_id_faces\person_17_id_face.jpg
# No face detected for person 18. Saved original image to extracted_id_faces\person_18_failed.jpg
# Extracted and saved face for person 19 at extracted_id_faces\person_19_id_face.jpg
# Extracted and saved face for person 20 at extracted_id_faces\person_20_id_face.jpg
# Extracted and saved face for person 21 at extracted_id_faces\person_21_id_face.jpg
# Extracted and saved face for person 22 at extracted_id_faces\person_22_id_face.jpg
# Extracted and saved face for person 23 at extracted_id_faces\person_23_id_face.jpg
# Extracted and saved face for person 24 at extracted_id_faces\person_24_id_face.jpg
# Extracted and saved face for person 25 at extracted_id_faces\person_25_id_face.jpg
# Extracted and saved face for person 26 at extracted_id_faces\person_26_id_face.jpg
# Extracted and saved face for person 27 at extracted_id_faces\person_27_id_face.jpg
# Extracted and saved face for person 28 at extracted_id_faces\person_28_id_face.jpg
# Extracted and saved face for person 29 at extracted_id_faces\person_29_id_face.jpg
# Extracted and saved face for person 30 at extracted_id_faces\person_30_id_face.jpg
# Extracted and saved face for person 31 at extracted_id_faces\person_31_id_face.jpg
# Extracted and saved face for person 32 at extracted_id_faces\person_32_id_face.jpg
# Extracted and saved face for person 33 at extracted_id_faces\person_33_id_face.jpg
# Extracted and saved face for person 34 at extracted_id_faces\person_34_id_face.jpg
# Extracted and saved face for person 35 at extracted_id_faces\person_35_id_face.jpg
# Extracted and saved face for person 36 at extracted_id_faces\person_36_id_face.jpg
# Extracted and saved face for person 37 at extracted_id_faces\person_37_id_face.jpg
# Extracted and saved face for person 38 at extracted_id_faces\person_38_id_face.jpg
# Extracted and saved face for person 39 at extracted_id_faces\person_39_id_face.jpg
# Extracted and saved face for person 40 at extracted_id_faces\person_40_id_face.jpg
# Extracted and saved face for person 41 at extracted_id_faces\person_41_id_face.jpg
# Extracted and saved face for person 42 at extracted_id_faces\person_42_id_face.jpg
# Extracted and saved face for person 43 at extracted_id_faces\person_43_id_face.jpg
# Extracted and saved face for person 44 at extracted_id_faces\person_44_id_face.jpg
# Extracted and saved face for person 45 at extracted_id_faces\person_45_id_face.jpg
# Extracted and saved face for person 46 at extracted_id_faces\person_46_id_face.jpg
# Extracted and saved face for person 47 at extracted_id_faces\person_47_id_face.jpg
# Extracted and saved face for person 48 at extracted_id_faces\person_48_id_face.jpg
# Extracted and saved face for person 49 at extracted_id_faces\person_49_id_face.jpg
# Extracted and saved face for person 50 at extracted_id_faces\person_50_id_face.jpg
# Extracted and saved face for person 51 at extracted_id_faces\person_51_id_face.jpg
# Extracted and saved face for person 52 at extracted_id_faces\person_52_id_face.jpg
# Extracted and saved face for person 53 at extracted_id_faces\person_53_id_face.jpg
# Extracted and saved face for person 54 at extracted_id_faces\person_54_id_face.jpg
# Extracted and saved face for person 55 at extracted_id_faces\person_55_id_face.jpg
# No face detected for person 56. Saved original image to extracted_id_faces\person_56_failed.jpg
# Extracted and saved face for person 57 at extracted_id_faces\person_57_id_face.jpg
# Extracted and saved face for person 58 at extracted_id_faces\person_58_id_face.jpg
# Extracted and saved face for person 59 at extracted_id_faces\person_59_id_face.jpg
# Extracted and saved face for person 60 at extracted_id_faces\person_60_id_face.jpg
# Extracted and saved face for person 61 at extracted_id_faces\person_61_id_face.jpg
# Extracted and saved face for person 62 at extracted_id_faces\person_62_id_face.jpg
# Extracted and saved face for person 63 at extracted_id_faces\person_63_id_face.jpg
# No face detected for person 64. Saved original image to extracted_id_faces\person_64_failed.jpg
# Extracted and saved face for person 65 at extracted_id_faces\person_65_id_face.jpg
# Extracted and saved face for person 66 at extracted_id_faces\person_66_id_face.jpg
# Extracted and saved face for person 67 at extracted_id_faces\person_67_id_face.jpg
# No face detected for person 68. Saved original image to extracted_id_faces\person_68_failed.jpg
# Extracted and saved face for person 69 at extracted_id_faces\person_69_id_face.jpg
# Extracted and saved face for person 70 at extracted_id_faces\person_70_id_face.jpg
# Extracted and saved face for person 71 at extracted_id_faces\person_71_id_face.jpg
# Extracted and saved face for person 72 at extracted_id_faces\person_72_id_face.jpg
# Extracted and saved face for person 73 at extracted_id_faces\person_73_id_face.jpg
# Extracted and saved face for person 74 at extracted_id_faces\person_74_id_face.jpg
# Extracted and saved face for person 75 at extracted_id_faces\person_75_id_face.jpg
# Extracted and saved face for person 76 at extracted_id_faces\person_76_id_face.jpg
# Extracted and saved face for person 77 at extracted_id_faces\person_77_id_face.jpg
# Extracted and saved face for person 78 at extracted_id_faces\person_78_id_face.jpg
# Extracted and saved face for person 79 at extracted_id_faces\person_79_id_face.jpg
# Extracted and saved face for person 80 at extracted_id_faces\person_80_id_face.jpg
# Extracted and saved face for person 81 at extracted_id_faces\person_81_id_face.jpg
# Extracted and saved face for person 82 at extracted_id_faces\person_82_id_face.jpg
# Extracted and saved face for person 83 at extracted_id_faces\person_83_id_face.jpg
# Extracted and saved face for person 84 at extracted_id_faces\person_84_id_face.jpg
# Extracted and saved face for person 85 at extracted_id_faces\person_85_id_face.jpg
# Extracted and saved face for person 86 at extracted_id_faces\person_86_id_face.jpg
# Extracted and saved face for person 87 at extracted_id_faces\person_87_id_face.jpg
# Extracted and saved face for person 88 at extracted_id_faces\person_88_id_face.jpg
# Extracted and saved face for person 89 at extracted_id_faces\person_89_id_face.jpg
# Extracted and saved face for person 90 at extracted_id_faces\person_90_id_face.jpg
# Extracted and saved face for person 91 at extracted_id_faces\person_91_id_face.jpg
# Extracted and saved face for person 92 at extracted_id_faces\person_92_id_face.jpg
# Extracted and saved face for person 93 at extracted_id_faces\person_93_id_face.jpg
# Extracted and saved face for person 94 at extracted_id_faces\person_94_id_face.jpg
# Extracted and saved face for person 95 at extracted_id_faces\person_95_id_face.jpg
# Extracted and saved face for person 96 at extracted_id_faces\person_96_id_face.jpg
# Extracted and saved face for person 97 at extracted_id_faces\person_97_id_face.jpg
# Extracted and saved face for person 98 at extracted_id_faces\person_98_id_face.jpg
# Extracted and saved face for person 99 at extracted_id_faces\person_99_id_face.jpg
# Extracted and saved face for person 100 at extracted_id_faces\person_100_id_face.jpg
# Extracted and saved face for person 101 at extracted_id_faces\person_101_id_face.jpg
# Extracted and saved face for person 102 at extracted_id_faces\person_102_id_face.jpg
# Extracted and saved face for person 103 at extracted_id_faces\person_103_id_face.jpg
# Extracted and saved face for person 104 at extracted_id_faces\person_104_id_face.jpg
# Extracted and saved face for person 105 at extracted_id_faces\person_105_id_face.jpg
# Extracted and saved face for person 106 at extracted_id_faces\person_106_id_face.jpg
# Extracted and saved face for person 107 at extracted_id_faces\person_107_id_face.jpg
# Extracted and saved face for person 108 at extracted_id_faces\person_108_id_face.jpg
# Extracted and saved face for person 109 at extracted_id_faces\person_109_id_face.jpg
# Extracted and saved face for person 110 at extracted_id_faces\person_110_id_face.jpg
# Extracted and saved face for person 111 at extracted_id_faces\person_111_id_face.jpg
# Extracted and saved face for person 112 at extracted_id_faces\person_112_id_face.jpg
# Extracted and saved face for person 113 at extracted_id_faces\person_113_id_face.jpg
# Extracted and saved face for person 114 at extracted_id_faces\person_114_id_face.jpg
# Extracted and saved face for person 115 at extracted_id_faces\person_115_id_face.jpg
# Extracted and saved face for person 116 at extracted_id_faces\person_116_id_face.jpg
# Extracted and saved face for person 117 at extracted_id_faces\person_117_id_face.jpg
# Extracted and saved face for person 118 at extracted_id_faces\person_118_id_face.jpg
# Extracted and saved face for person 119 at extracted_id_faces\person_119_id_face.jpg
# Extracted and saved face for person 120 at extracted_id_faces\person_120_id_face.jpg
# Extracted and saved face for person 121 at extracted_id_faces\person_121_id_face.jpg
# Extracted and saved face for person 122 at extracted_id_faces\person_122_id_face.jpg
# Extracted and saved face for person 123 at extracted_id_faces\person_123_id_face.jpg
# Extracted and saved face for person 124 at extracted_id_faces\person_124_id_face.jpg
# Extracted and saved face for person 125 at extracted_id_faces\person_125_id_face.jpg
# Extracted and saved face for person 126 at extracted_id_faces\person_126_id_face.jpg
# Extracted and saved face for person 127 at extracted_id_faces\person_127_id_face.jpg
# Extracted and saved face for person 128 at extracted_id_faces\person_128_id_face.jpg
# Extracted and saved face for person 129 at extracted_id_faces\person_129_id_face.jpg
# Extracted and saved face for person 130 at extracted_id_faces\person_130_id_face.jpg
# Extracted and saved face for person 131 at extracted_id_faces\person_131_id_face.jpg
# Extracted and saved face for person 132 at extracted_id_faces\person_132_id_face.jpg
# Extracted and saved face for person 133 at extracted_id_faces\person_133_id_face.jpg
# Extracted and saved face for person 134 at extracted_id_faces\person_134_id_face.jpg
# Extracted and saved face for person 135 at extracted_id_faces\person_135_id_face.jpg
# Extracted and saved face for person 136 at extracted_id_faces\person_136_id_face.jpg
# Extracted and saved face for person 137 at extracted_id_faces\person_137_id_face.jpg
# Extracted and saved face for person 138 at extracted_id_faces\person_138_id_face.jpg
# Extracted and saved face for person 139 at extracted_id_faces\person_139_id_face.jpg
# Extracted and saved face for person 140 at extracted_id_faces\person_140_id_face.jpg
# Extracted and saved face for person 141 at extracted_id_faces\person_141_id_face.jpg
# Extracted and saved face for person 142 at extracted_id_faces\person_142_id_face.jpg
# Extracted and saved face for person 143 at extracted_id_faces\person_143_id_face.jpg
# Extracted and saved face for person 144 at extracted_id_faces\person_144_id_face.jpg
# Extracted and saved face for person 145 at extracted_id_faces\person_145_id_face.jpg
# Extracted and saved face for person 146 at extracted_id_faces\person_146_id_face.jpg
# Extracted and saved face for person 147 at extracted_id_faces\person_147_id_face.jpg
# Extracted and saved face for person 148 at extracted_id_faces\person_148_id_face.jpg
# Extracted and saved face for person 149 at extracted_id_faces\person_149_id_face.jpg
# Extracted and saved face for person 150 at extracted_id_faces\person_150_id_face.jpg
# Extracted and saved face for person 151 at extracted_id_faces\person_151_id_face.jpg
# Extracted and saved face for person 152 at extracted_id_faces\person_152_id_face.jpg
# Extracted and saved face for person 153 at extracted_id_faces\person_153_id_face.jpg
# Extracted and saved face for person 154 at extracted_id_faces\person_154_id_face.jpg
# Extracted and saved face for person 155 at extracted_id_faces\person_155_id_face.jpg
# Extracted and saved face for person 156 at extracted_id_faces\person_156_id_face.jpg
# Extracted and saved face for person 157 at extracted_id_faces\person_157_id_face.jpg
# Extracted and saved face for person 158 at extracted_id_faces\person_158_id_face.jpg
# Extracted and saved face for person 159 at extracted_id_faces\person_159_id_face.jpg
# Extracted and saved face for person 160 at extracted_id_faces\person_160_id_face.jpg
# Extracted and saved face for person 161 at extracted_id_faces\person_161_id_face.jpg
# Extracted and saved face for person 162 at extracted_id_faces\person_162_id_face.jpg
# Extracted and saved face for person 163 at extracted_id_faces\person_163_id_face.jpg
# Extracted and saved face for person 164 at extracted_id_faces\person_164_id_face.jpg
# Extracted and saved face for person 165 at extracted_id_faces\person_165_id_face.jpg
# Extracted and saved face for person 166 at extracted_id_faces\person_166_id_face.jpg
# Extracted and saved face for person 167 at extracted_id_faces\person_167_id_face.jpg
# Extracted and saved face for person 168 at extracted_id_faces\person_168_id_face.jpg
# Extracted and saved face for person 169 at extracted_id_faces\person_169_id_face.jpg
# Extracted and saved face for person 170 at extracted_id_faces\person_170_id_face.jpg
# Extracted and saved face for person 171 at extracted_id_faces\person_171_id_face.jpg
# Extracted and saved face for person 172 at extracted_id_faces\person_172_id_face.jpg
# Extracted and saved face for person 173 at extracted_id_faces\person_173_id_face.jpg
# Extracted and saved face for person 174 at extracted_id_faces\person_174_id_face.jpg
# Extracted and saved face for person 175 at extracted_id_faces\person_175_id_face.jpg
# Extracted and saved face for person 176 at extracted_id_faces\person_176_id_face.jpg
# Extracted and saved face for person 177 at extracted_id_faces\person_177_id_face.jpg
# Extracted and saved face for person 178 at extracted_id_faces\person_178_id_face.jpg
# Extracted and saved face for person 179 at extracted_id_faces\person_179_id_face.jpg
# Extracted and saved face for person 180 at extracted_id_faces\person_180_id_face.jpg
# Extracted and saved face for person 181 at extracted_id_faces\person_181_id_face.jpg
# Extracted and saved face for person 182 at extracted_id_faces\person_182_id_face.jpg
# No face detected for person 183. Saved original image to extracted_id_faces\person_183_failed.jpg
# Extracted and saved face for person 184 at extracted_id_faces\person_184_id_face.jpg
# Extracted and saved face for person 185 at extracted_id_faces\person_185_id_face.jpg
# Extracted and saved face for person 186 at extracted_id_faces\person_186_id_face.jpg
# Extracted and saved face for person 187 at extracted_id_faces\person_187_id_face.jpg
# Extracted and saved face for person 188 at extracted_id_faces\person_188_id_face.jpg
# Extracted and saved face for person 189 at extracted_id_faces\person_189_id_face.jpg
# Extracted and saved face for person 190 at extracted_id_faces\person_190_id_face.jpg
# Extracted and saved face for person 191 at extracted_id_faces\person_191_id_face.jpg
# Extracted and saved face for person 192 at extracted_id_faces\person_192_id_face.jpg
# Extracted and saved face for person 193 at extracted_id_faces\person_193_id_face.jpg
# Extracted and saved face for person 194 at extracted_id_faces\person_194_id_face.jpg
# Extracted and saved face for person 195 at extracted_id_faces\person_195_id_face.jpg
# Extracted and saved face for person 196 at extracted_id_faces\person_196_id_face.jpg
# Extracted and saved face for person 197 at extracted_id_faces\person_197_id_face.jpg
# Extracted and saved face for person 198 at extracted_id_faces\person_198_id_face.jpg
# No face detected for person 199. Saved original image to extracted_id_faces\person_199_failed.jpg
# Extracted and saved face for person 200 at extracted_id_faces\person_200_id_face.jpg
# Extracted and saved face for person 201 at extracted_id_faces\person_201_id_face.jpg
# Extracted and saved face for person 202 at extracted_id_faces\person_202_id_face.jpg
# Extracted and saved face for person 203 at extracted_id_faces\person_203_id_face.jpg
# No face detected for person 204. Saved original image to extracted_id_faces\person_204_failed.jpg
# Extracted and saved face for person 205 at extracted_id_faces\person_205_id_face.jpg
# Extracted and saved face for person 206 at extracted_id_faces\person_206_id_face.jpg
# Extracted and saved face for person 207 at extracted_id_faces\person_207_id_face.jpg
# Extracted and saved face for person 208 at extracted_id_faces\person_208_id_face.jpg
# Extracted and saved face for person 209 at extracted_id_faces\person_209_id_face.jpg
# Extracted and saved face for person 210 at extracted_id_faces\person_210_id_face.jpg
# Extracted and saved face for person 211 at extracted_id_faces\person_211_id_face.jpg
# Extracted and saved face for person 212 at extracted_id_faces\person_212_id_face.jpg
# Extracted and saved face for person 213 at extracted_id_faces\person_213_id_face.jpg
# Extracted and saved face for person 214 at extracted_id_faces\person_214_id_face.jpg
# Extracted and saved face for person 215 at extracted_id_faces\person_215_id_face.jpg
# Extracted and saved face for person 216 at extracted_id_faces\person_216_id_face.jpg
# Extracted and saved face for person 217 at extracted_id_faces\person_217_id_face.jpg
# Extracted and saved face for person 218 at extracted_id_faces\person_218_id_face.jpg
# Extracted and saved face for person 219 at extracted_id_faces\person_219_id_face.jpg
# Extracted and saved face for person 220 at extracted_id_faces\person_220_id_face.jpg
# Extracted and saved face for person 221 at extracted_id_faces\person_221_id_face.jpg
# Extracted and saved face for person 222 at extracted_id_faces\person_222_id_face.jpg
# Extracted and saved face for person 223 at extracted_id_faces\person_223_id_face.jpg
# Extracted and saved face for person 224 at extracted_id_faces\person_224_id_face.jpg
# Extracted and saved face for person 225 at extracted_id_faces\person_225_id_face.jpg
# Extracted and saved face for person 226 at extracted_id_faces\person_226_id_face.jpg
# Extracted and saved face for person 227 at extracted_id_faces\person_227_id_face.jpg
# Extracted and saved face for person 228 at extracted_id_faces\person_228_id_face.jpg
# Extracted and saved face for person 229 at extracted_id_faces\person_229_id_face.jpg
# Extracted and saved face for person 230 at extracted_id_faces\person_230_id_face.jpg
# Extracted and saved face for person 231 at extracted_id_faces\person_231_id_face.jpg
# Extracted and saved face for person 232 at extracted_id_faces\person_232_id_face.jpg
# Extracted and saved face for person 233 at extracted_id_faces\person_233_id_face.jpg
# Extracted and saved face for person 234 at extracted_id_faces\person_234_id_face.jpg
# Extracted and saved face for person 235 at extracted_id_faces\person_235_id_face.jpg
# Extracted and saved face for person 236 at extracted_id_faces\person_236_id_face.jpg
# Extracted and saved face for person 237 at extracted_id_faces\person_237_id_face.jpg
# Extracted and saved face for person 238 at extracted_id_faces\person_238_id_face.jpg
# Extracted and saved face for person 239 at extracted_id_faces\person_239_id_face.jpg
# Extracted and saved face for person 240 at extracted_id_faces\person_240_id_face.jpg
# Extracted and saved face for person 241 at extracted_id_faces\person_241_id_face.jpg
# Extracted and saved face for person 242 at extracted_id_faces\person_242_id_face.jpg
# Extracted and saved face for person 243 at extracted_id_faces\person_243_id_face.jpg
# Extracted and saved face for person 244 at extracted_id_faces\person_244_id_face.jpg
# Extracted and saved face for person 245 at extracted_id_faces\person_245_id_face.jpg
# Extracted and saved face for person 246 at extracted_id_faces\person_246_id_face.jpg
# Extracted and saved face for person 247 at extracted_id_faces\person_247_id_face.jpg
# Extracted and saved face for person 248 at extracted_id_faces\person_248_id_face.jpg
# Extracted and saved face for person 249 at extracted_id_faces\person_249_id_face.jpg
# Extracted and saved face for person 250 at extracted_id_faces\person_250_id_face.jpg
# Extracted and saved face for person 251 at extracted_id_faces\person_251_id_face.jpg
# Extracted and saved face for person 252 at extracted_id_faces\person_252_id_face.jpg
# Extracted and saved face for person 253 at extracted_id_faces\person_253_id_face.jpg
# Extracted and saved face for person 254 at extracted_id_faces\person_254_id_face.jpg
# Extracted and saved face for person 255 at extracted_id_faces\person_255_id_face.jpg
# Extracted and saved face for person 256 at extracted_id_faces\person_256_id_face.jpg
# Extracted and saved face for person 257 at extracted_id_faces\person_257_id_face.jpg
# No face detected for person 258. Saved original image to extracted_id_faces\person_258_failed.jpg
# Extracted and saved face for person 259 at extracted_id_faces\person_259_id_face.jpg
# Extracted and saved face for person 260 at extracted_id_faces\person_260_id_face.jpg
# Extracted and saved face for person 261 at extracted_id_faces\person_261_id_face.jpg
# Extracted and saved face for person 262 at extracted_id_faces\person_262_id_face.jpg
# Extracted and saved face for person 263 at extracted_id_faces\person_263_id_face.jpg
# Extracted and saved face for person 264 at extracted_id_faces\person_264_id_face.jpg
# Extracted and saved face for person 265 at extracted_id_faces\person_265_id_face.jpg
# Extracted and saved face for person 266 at extracted_id_faces\person_266_id_face.jpg
# Extracted and saved face for person 267 at extracted_id_faces\person_267_id_face.jpg
# Extracted and saved face for person 268 at extracted_id_faces\person_268_id_face.jpg
# Extracted and saved face for person 269 at extracted_id_faces\person_269_id_face.jpg
# No face detected for person 270. Saved original image to extracted_id_faces\person_270_failed.jpg
# Extracted and saved face for person 271 at extracted_id_faces\person_271_id_face.jpg
# Extracted and saved face for person 272 at extracted_id_faces\person_272_id_face.jpg
# Extracted and saved face for person 273 at extracted_id_faces\person_273_id_face.jpg
# Extracted and saved face for person 274 at extracted_id_faces\person_274_id_face.jpg
# Extracted and saved face for person 275 at extracted_id_faces\person_275_id_face.jpg
# Extracted and saved face for person 276 at extracted_id_faces\person_276_id_face.jpg
# Extracted and saved face for person 277 at extracted_id_faces\person_277_id_face.jpg
# Extracted and saved face for person 278 at extracted_id_faces\person_278_id_face.jpg
# Extracted and saved face for person 279 at extracted_id_faces\person_279_id_face.jpg
# Extracted and saved face for person 280 at extracted_id_faces\person_280_id_face.jpg
# Extracted and saved face for person 281 at extracted_id_faces\person_281_id_face.jpg
# Extracted and saved face for person 282 at extracted_id_faces\person_282_id_face.jpg
# Extracted and saved face for person 283 at extracted_id_faces\person_283_id_face.jpg
# Extracted and saved face for person 284 at extracted_id_faces\person_284_id_face.jpg
# Extracted and saved face for person 285 at extracted_id_faces\person_285_id_face.jpg
# Extracted and saved face for person 286 at extracted_id_faces\person_286_id_face.jpg
# Extracted and saved face for person 287 at extracted_id_faces\person_287_id_face.jpg
# Extracted and saved face for person 288 at extracted_id_faces\person_288_id_face.jpg
# Extracted and saved face for person 289 at extracted_id_faces\person_289_id_face.jpg
# Extracted and saved face for person 290 at extracted_id_faces\person_290_id_face.jpg
# Extracted and saved face for person 291 at extracted_id_faces\person_291_id_face.jpg
# Extracted and saved face for person 292 at extracted_id_faces\person_292_id_face.jpg
# Extracted and saved face for person 293 at extracted_id_faces\person_293_id_face.jpg
# Extracted and saved face for person 294 at extracted_id_faces\person_294_id_face.jpg
# Extracted and saved face for person 295 at extracted_id_faces\person_295_id_face.jpg
# Extracted and saved face for person 296 at extracted_id_faces\person_296_id_face.jpg
# Extracted and saved face for person 297 at extracted_id_faces\person_297_id_face.jpg
# Extracted and saved face for person 298 at extracted_id_faces\person_298_id_face.jpg
# Extracted and saved face for person 299 at extracted_id_faces\person_299_id_face.jpg
# Extracted and saved face for person 300 at extracted_id_faces\person_300_id_face.jpg
# Extracted and saved face for person 301 at extracted_id_faces\person_301_id_face.jpg
# Extracted and saved face for person 302 at extracted_id_faces\person_302_id_face.jpg
# Extracted and saved face for person 303 at extracted_id_faces\person_303_id_face.jpg
# Extracted and saved face for person 304 at extracted_id_faces\person_304_id_face.jpg
# Extracted and saved face for person 305 at extracted_id_faces\person_305_id_face.jpg
# Extracted and saved face for person 306 at extracted_id_faces\person_306_id_face.jpg
# Extracted and saved face for person 307 at extracted_id_faces\person_307_id_face.jpg
# Extracted and saved face for person 308 at extracted_id_faces\person_308_id_face.jpg
# Extracted and saved face for person 309 at extracted_id_faces\person_309_id_face.jpg
# Extracted and saved face for person 310 at extracted_id_faces\person_310_id_face.jpg
# Extracted and saved face for person 311 at extracted_id_faces\person_311_id_face.jpg
# Extracted and saved face for person 312 at extracted_id_faces\person_312_id_face.jpg
# Extracted and saved face for person 313 at extracted_id_faces\person_313_id_face.jpg
# Extracted and saved face for person 314 at extracted_id_faces\person_314_id_face.jpg
# Extracted and saved face for person 315 at extracted_id_faces\person_315_id_face.jpg
# Extracted and saved face for person 316 at extracted_id_faces\person_316_id_face.jpg
# Extracted and saved face for person 317 at extracted_id_faces\person_317_id_face.jpg
# Extracted and saved face for person 318 at extracted_id_faces\person_318_id_face.jpg
# Extracted and saved face for person 319 at extracted_id_faces\person_319_id_face.jpg
# Extracted and saved face for person 320 at extracted_id_faces\person_320_id_face.jpg
# Extracted and saved face for person 321 at extracted_id_faces\person_321_id_face.jpg
# Extracted and saved face for person 322 at extracted_id_faces\person_322_id_face.jpg
# Extracted and saved face for person 323 at extracted_id_faces\person_323_id_face.jpg
# Extracted and saved face for person 324 at extracted_id_faces\person_324_id_face.jpg
# No face detected for person 325. Saved original image to extracted_id_faces\person_325_failed.jpg
# Extracted and saved face for person 326 at extracted_id_faces\person_326_id_face.jpg
# Extracted and saved face for person 327 at extracted_id_faces\person_327_id_face.jpg
# Extracted and saved face for person 328 at extracted_id_faces\person_328_id_face.jpg
# Extracted and saved face for person 329 at extracted_id_faces\person_329_id_face.jpg
# Extracted and saved face for person 330 at extracted_id_faces\person_330_id_face.jpg
# Extracted and saved face for person 331 at extracted_id_faces\person_331_id_face.jpg
# Extracted and saved face for person 332 at extracted_id_faces\person_332_id_face.jpg
# Extracted and saved face for person 333 at extracted_id_faces\person_333_id_face.jpg
# Extracted and saved face for person 334 at extracted_id_faces\person_334_id_face.jpg
# Extracted and saved face for person 335 at extracted_id_faces\person_335_id_face.jpg
# Extracted and saved face for person 336 at extracted_id_faces\person_336_id_face.jpg
# Extracted and saved face for person 337 at extracted_id_faces\person_337_id_face.jpg
# Extracted and saved face for person 338 at extracted_id_faces\person_338_id_face.jpg
# Extracted and saved face for person 339 at extracted_id_faces\person_339_id_face.jpg
# Extracted and saved face for person 340 at extracted_id_faces\person_340_id_face.jpg
# Extracted and saved face for person 341 at extracted_id_faces\person_341_id_face.jpg
# Extracted and saved face for person 342 at extracted_id_faces\person_342_id_face.jpg
# Extracted and saved face for person 343 at extracted_id_faces\person_343_id_face.jpg
# Extracted and saved face for person 344 at extracted_id_faces\person_344_id_face.jpg
# Extracted and saved face for person 345 at extracted_id_faces\person_345_id_face.jpg
# Extracted and saved face for person 346 at extracted_id_faces\person_346_id_face.jpg
# Extracted and saved face for person 347 at extracted_id_faces\person_347_id_face.jpg
# Extracted and saved face for person 348 at extracted_id_faces\person_348_id_face.jpg
# Extracted and saved face for person 349 at extracted_id_faces\person_349_id_face.jpg
# Extracted and saved face for person 350 at extracted_id_faces\person_350_id_face.jpg
# Extracted and saved face for person 351 at extracted_id_faces\person_351_id_face.jpg
# Extracted and saved face for person 352 at extracted_id_faces\person_352_id_face.jpg
# Extracted and saved face for person 353 at extracted_id_faces\person_353_id_face.jpg
# Extracted and saved face for person 354 at extracted_id_faces\person_354_id_face.jpg
# Extracted and saved face for person 355 at extracted_id_faces\person_355_id_face.jpg
# Extracted and saved face for person 356 at extracted_id_faces\person_356_id_face.jpg
# Extracted and saved face for person 357 at extracted_id_faces\person_357_id_face.jpg
# Extracted and saved face for person 358 at extracted_id_faces\person_358_id_face.jpg
# Extracted and saved face for person 359 at extracted_id_faces\person_359_id_face.jpg
# Extracted and saved face for person 360 at extracted_id_faces\person_360_id_face.jpg
# Extracted and saved face for person 361 at extracted_id_faces\person_361_id_face.jpg
# Extracted and saved face for person 362 at extracted_id_faces\person_362_id_face.jpg
# Extracted and saved face for person 363 at extracted_id_faces\person_363_id_face.jpg
# Extracted and saved face for person 364 at extracted_id_faces\person_364_id_face.jpg
# Extracted and saved face for person 365 at extracted_id_faces\person_365_id_face.jpg
# Extracted and saved face for person 366 at extracted_id_faces\person_366_id_face.jpg
# Extracted and saved face for person 367 at extracted_id_faces\person_367_id_face.jpg
# Extracted and saved face for person 368 at extracted_id_faces\person_368_id_face.jpg
# Extracted and saved face for person 369 at extracted_id_faces\person_369_id_face.jpg
# Extracted and saved face for person 370 at extracted_id_faces\person_370_id_face.jpg
# Extracted and saved face for person 371 at extracted_id_faces\person_371_id_face.jpg
# Extracted and saved face for person 372 at extracted_id_faces\person_372_id_face.jpg
# Extracted and saved face for person 373 at extracted_id_faces\person_373_id_face.jpg
# Extracted and saved face for person 374 at extracted_id_faces\person_374_id_face.jpg
# Extracted and saved face for person 375 at extracted_id_faces\person_375_id_face.jpg
# Extracted and saved face for person 376 at extracted_id_faces\person_376_id_face.jpg
# Extracted and saved face for person 377 at extracted_id_faces\person_377_id_face.jpg
# Extracted and saved face for person 378 at extracted_id_faces\person_378_id_face.jpg
# Extracted and saved face for person 379 at extracted_id_faces\person_379_id_face.jpg
# Extracted and saved face for person 380 at extracted_id_faces\person_380_id_face.jpg
# Extracted and saved face for person 381 at extracted_id_faces\person_381_id_face.jpg
# Extracted and saved face for person 382 at extracted_id_faces\person_382_id_face.jpg
# Extracted and saved face for person 383 at extracted_id_faces\person_383_id_face.jpg
# Extracted and saved face for person 384 at extracted_id_faces\person_384_id_face.jpg
# Extracted and saved face for person 385 at extracted_id_faces\person_385_id_face.jpg
# Extracted and saved face for person 386 at extracted_id_faces\person_386_id_face.jpg
# Extracted and saved face for person 387 at extracted_id_faces\person_387_id_face.jpg
# Extracted and saved face for person 388 at extracted_id_faces\person_388_id_face.jpg
# Extracted and saved face for person 389 at extracted_id_faces\person_389_id_face.jpg
# Extracted and saved face for person 390 at extracted_id_faces\person_390_id_face.jpg
# Extracted and saved face for person 391 at extracted_id_faces\person_391_id_face.jpg
# Extracted and saved face for person 392 at extracted_id_faces\person_392_id_face.jpg
# Extracted and saved face for person 393 at extracted_id_faces\person_393_id_face.jpg
# Extracted and saved face for person 394 at extracted_id_faces\person_394_id_face.jpg
# Extracted and saved face for person 395 at extracted_id_faces\person_395_id_face.jpg
# Extracted and saved face for person 396 at extracted_id_faces\person_396_id_face.jpg
# Extracted and saved face for person 397 at extracted_id_faces\person_397_id_face.jpg
# Extracted and saved face for person 398 at extracted_id_faces\person_398_id_face.jpg
# Extracted and saved face for person 399 at extracted_id_faces\person_399_id_face.jpg
# Extracted and saved face for person 400 at extracted_id_faces\person_400_id_face.jpg
# Extracted and saved face for person 401 at extracted_id_faces\person_401_id_face.jpg
# Extracted and saved face for person 402 at extracted_id_faces\person_402_id_face.jpg
# No face detected for person 403. Saved original image to extracted_id_faces\person_403_failed.jpg
# Extracted and saved face for person 404 at extracted_id_faces\person_404_id_face.jpg
# No face detected for person 405. Saved original image to extracted_id_faces\person_405_failed.jpg
# Extracted and saved face for person 406 at extracted_id_faces\person_406_id_face.jpg
# Extracted and saved face for person 407 at extracted_id_faces\person_407_id_face.jpg
# Extracted and saved face for person 408 at extracted_id_faces\person_408_id_face.jpg
# Extracted and saved face for person 409 at extracted_id_faces\person_409_id_face.jpg
# No face detected for person 410. Saved original image to extracted_id_faces\person_410_failed.jpg
# Extracted and saved face for person 411 at extracted_id_faces\person_411_id_face.jpg
# Extracted and saved face for person 412 at extracted_id_faces\person_412_id_face.jpg
# Extracted and saved face for person 413 at extracted_id_faces\person_413_id_face.jpg
# Extracted and saved face for person 414 at extracted_id_faces\person_414_id_face.jpg
# Extracted and saved face for person 415 at extracted_id_faces\person_415_id_face.jpg
# Extracted and saved face for person 416 at extracted_id_faces\person_416_id_face.jpg
# Extracted and saved face for person 417 at extracted_id_faces\person_417_id_face.jpg
# Extracted and saved face for person 418 at extracted_id_faces\person_418_id_face.jpg
# Extracted and saved face for person 419 at extracted_id_faces\person_419_id_face.jpg
# Extracted and saved face for person 420 at extracted_id_faces\person_420_id_face.jpg
# Extracted and saved face for person 421 at extracted_id_faces\person_421_id_face.jpg
# Extracted and saved face for person 422 at extracted_id_faces\person_422_id_face.jpg
# Extracted and saved face for person 423 at extracted_id_faces\person_423_id_face.jpg
# Extracted and saved face for person 424 at extracted_id_faces\person_424_id_face.jpg
# Extracted and saved face for person 425 at extracted_id_faces\person_425_id_face.jpg
# Extracted and saved face for person 426 at extracted_id_faces\person_426_id_face.jpg
# Extracted and saved face for person 427 at extracted_id_faces\person_427_id_face.jpg
# Extracted and saved face for person 428 at extracted_id_faces\person_428_id_face.jpg
# Extracted and saved face for person 429 at extracted_id_faces\person_429_id_face.jpg
# Extracted and saved face for person 430 at extracted_id_faces\person_430_id_face.jpg
# Extracted and saved face for person 431 at extracted_id_faces\person_431_id_face.jpg
# Extracted and saved face for person 432 at extracted_id_faces\person_432_id_face.jpg
# Extracted and saved face for person 433 at extracted_id_faces\person_433_id_face.jpg
# No face detected for person 434. Saved original image to extracted_id_faces\person_434_failed.jpg
# Extracted and saved face for person 435 at extracted_id_faces\person_435_id_face.jpg
# Extracted and saved face for person 436 at extracted_id_faces\person_436_id_face.jpg
# Extracted and saved face for person 437 at extracted_id_faces\person_437_id_face.jpg
# Extracted and saved face for person 438 at extracted_id_faces\person_438_id_face.jpg
# Extracted and saved face for person 439 at extracted_id_faces\person_439_id_face.jpg
# Extracted and saved face for person 440 at extracted_id_faces\person_440_id_face.jpg
# Extracted and saved face for person 441 at extracted_id_faces\person_441_id_face.jpg
# Extracted and saved face for person 442 at extracted_id_faces\person_442_id_face.jpg
# Extracted and saved face for person 443 at extracted_id_faces\person_443_id_face.jpg
# Extracted and saved face for person 444 at extracted_id_faces\person_444_id_face.jpg
# Extracted and saved face for person 445 at extracted_id_faces\person_445_id_face.jpg
# Extracted and saved face for person 446 at extracted_id_faces\person_446_id_face.jpg
# Extracted and saved face for person 447 at extracted_id_faces\person_447_id_face.jpg
# No face detected for person 448. Saved original image to extracted_id_faces\person_448_failed.jpg
# Extracted and saved face for person 449 at extracted_id_faces\person_449_id_face.jpg
# Extracted and saved face for person 450 at extracted_id_faces\person_450_id_face.jpg
# Extracted and saved face for person 451 at extracted_id_faces\person_451_id_face.jpg
# Extracted and saved face for person 452 at extracted_id_faces\person_452_id_face.jpg
# Extracted and saved face for person 453 at extracted_id_faces\person_453_id_face.jpg
# Extracted and saved face for person 454 at extracted_id_faces\person_454_id_face.jpg
# Extracted and saved face for person 455 at extracted_id_faces\person_455_id_face.jpg
# Extracted and saved face for person 456 at extracted_id_faces\person_456_id_face.jpg
# Extracted and saved face for person 457 at extracted_id_faces\person_457_id_face.jpg
# Extracted and saved face for person 458 at extracted_id_faces\person_458_id_face.jpg
# Extracted and saved face for person 459 at extracted_id_faces\person_459_id_face.jpg
# No face detected for person 460. Saved original image to extracted_id_faces\person_460_failed.jpg
# Extracted and saved face for person 461 at extracted_id_faces\person_461_id_face.jpg
# Extracted and saved face for person 462 at extracted_id_faces\person_462_id_face.jpg
# Extracted and saved face for person 463 at extracted_id_faces\person_463_id_face.jpg
# Extracted and saved face for person 464 at extracted_id_faces\person_464_id_face.jpg
# Extracted and saved face for person 465 at extracted_id_faces\person_465_id_face.jpg
# Extracted and saved face for person 466 at extracted_id_faces\person_466_id_face.jpg
# Extracted and saved face for person 467 at extracted_id_faces\person_467_id_face.jpg
# Extracted and saved face for person 468 at extracted_id_faces\person_468_id_face.jpg
# Extracted and saved face for person 469 at extracted_id_faces\person_469_id_face.jpg
# Extracted and saved face for person 470 at extracted_id_faces\person_470_id_face.jpg
# Extracted and saved face for person 471 at extracted_id_faces\person_471_id_face.jpg
# Extracted and saved face for person 472 at extracted_id_faces\person_472_id_face.jpg
# Extracted and saved face for person 473 at extracted_id_faces\person_473_id_face.jpg
# Extracted and saved face for person 474 at extracted_id_faces\person_474_id_face.jpg
# Extracted and saved face for person 475 at extracted_id_faces\person_475_id_face.jpg
# Extracted and saved face for person 476 at extracted_id_faces\person_476_id_face.jpg
# Extracted and saved face for person 477 at extracted_id_faces\person_477_id_face.jpg
# Extracted and saved face for person 478 at extracted_id_faces\person_478_id_face.jpg
# Extracted and saved face for person 479 at extracted_id_faces\person_479_id_face.jpg
# Extracted and saved face for person 480 at extracted_id_faces\person_480_id_face.jpg
# Extracted and saved face for person 481 at extracted_id_faces\person_481_id_face.jpg
# Extracted and saved face for person 482 at extracted_id_faces\person_482_id_face.jpg
# Extracted and saved face for person 483 at extracted_id_faces\person_483_id_face.jpg
# Extracted and saved face for person 484 at extracted_id_faces\person_484_id_face.jpg
# Extracted and saved face for person 485 at extracted_id_faces\person_485_id_face.jpg
# Extracted and saved face for person 486 at extracted_id_faces\person_486_id_face.jpg
# Extracted and saved face for person 487 at extracted_id_faces\person_487_id_face.jpg
# Extracted and saved face for person 488 at extracted_id_faces\person_488_id_face.jpg
# Extracted and saved face for person 489 at extracted_id_faces\person_489_id_face.jpg
# Extracted and saved face for person 490 at extracted_id_faces\person_490_id_face.jpg
# Extracted and saved face for person 491 at extracted_id_faces\person_491_id_face.jpg
# Extracted and saved face for person 492 at extracted_id_faces\person_492_id_face.jpg
# Extracted and saved face for person 493 at extracted_id_faces\person_493_id_face.jpg
# Extracted and saved face for person 494 at extracted_id_faces\person_494_id_face.jpg
# Extracted and saved face for person 495 at extracted_id_faces\person_495_id_face.jpg
# Extracted and saved face for person 496 at extracted_id_faces\person_496_id_face.jpg
# Extracted and saved face for person 497 at extracted_id_faces\person_497_id_face.jpg
# Extracted and saved face for person 498 at extracted_id_faces\person_498_id_face.jpg
# Extracted and saved face for person 499 at extracted_id_faces\person_499_id_face.jpg
# Extracted and saved face for person 500 at extracted_id_faces\person_500_id_face.jpg
# Extracted and saved face for person 501 at extracted_id_faces\person_501_id_face.jpg
# Extracted and saved face for person 502 at extracted_id_faces\person_502_id_face.jpg
# Extracted and saved face for person 503 at extracted_id_faces\person_503_id_face.jpg
# Extracted and saved face for person 504 at extracted_id_faces\person_504_id_face.jpg
# Extracted and saved face for person 505 at extracted_id_faces\person_505_id_face.jpg
# Extracted and saved face for person 506 at extracted_id_faces\person_506_id_face.jpg
# Extracted and saved face for person 507 at extracted_id_faces\person_507_id_face.jpg
# Extracted and saved face for person 508 at extracted_id_faces\person_508_id_face.jpg
# Extracted and saved face for person 509 at extracted_id_faces\person_509_id_face.jpg
# Extracted and saved face for person 510 at extracted_id_faces\person_510_id_face.jpg
# Extracted and saved face for person 511 at extracted_id_faces\person_511_id_face.jpg
# No face detected for person 512. Saved original image to extracted_id_faces\person_512_failed.jpg
# Extracted and saved face for person 513 at extracted_id_faces\person_513_id_face.jpg
# Extracted and saved face for person 514 at extracted_id_faces\person_514_id_face.jpg
# Extracted and saved face for person 515 at extracted_id_faces\person_515_id_face.jpg
# Extracted and saved face for person 516 at extracted_id_faces\person_516_id_face.jpg
# Extracted and saved face for person 517 at extracted_id_faces\person_517_id_face.jpg
# Extracted and saved face for person 518 at extracted_id_faces\person_518_id_face.jpg
# Extracted and saved face for person 519 at extracted_id_faces\person_519_id_face.jpg
# Extracted and saved face for person 520 at extracted_id_faces\person_520_id_face.jpg
# Extracted and saved face for person 521 at extracted_id_faces\person_521_id_face.jpg
# Extracted and saved face for person 522 at extracted_id_faces\person_522_id_face.jpg
# Extracted and saved face for person 523 at extracted_id_faces\person_523_id_face.jpg
# Extracted and saved face for person 524 at extracted_id_faces\person_524_id_face.jpg
# Extracted and saved face for person 525 at extracted_id_faces\person_525_id_face.jpg
# Extracted and saved face for person 526 at extracted_id_faces\person_526_id_face.jpg
# Extracted and saved face for person 527 at extracted_id_faces\person_527_id_face.jpg
# Extracted and saved face for person 528 at extracted_id_faces\person_528_id_face.jpg
# Extracted and saved face for person 529 at extracted_id_faces\person_529_id_face.jpg
# Extracted and saved face for person 530 at extracted_id_faces\person_530_id_face.jpg
# Extracted and saved face for person 531 at extracted_id_faces\person_531_id_face.jpg
# Extracted and saved face for person 532 at extracted_id_faces\person_532_id_face.jpg
# Extracted and saved face for person 533 at extracted_id_faces\person_533_id_face.jpg
# Extracted and saved face for person 534 at extracted_id_faces\person_534_id_face.jpg
# Extracted and saved face for person 535 at extracted_id_faces\person_535_id_face.jpg
# Extracted and saved face for person 536 at extracted_id_faces\person_536_id_face.jpg
# Extracted and saved face for person 537 at extracted_id_faces\person_537_id_face.jpg
# Extracted and saved face for person 538 at extracted_id_faces\person_538_id_face.jpg
# Extracted and saved face for person 539 at extracted_id_faces\person_539_id_face.jpg
# Extracted and saved face for person 540 at extracted_id_faces\person_540_id_face.jpg
# Extracted and saved face for person 541 at extracted_id_faces\person_541_id_face.jpg
# Extracted and saved face for person 542 at extracted_id_faces\person_542_id_face.jpg
# Extracted and saved face for person 543 at extracted_id_faces\person_543_id_face.jpg
# Extracted and saved face for person 544 at extracted_id_faces\person_544_id_face.jpg
# Extracted and saved face for person 545 at extracted_id_faces\person_545_id_face.jpg
# Extracted and saved face for person 546 at extracted_id_faces\person_546_id_face.jpg
# Extracted and saved face for person 547 at extracted_id_faces\person_547_id_face.jpg
# Extracted and saved face for person 548 at extracted_id_faces\person_548_id_face.jpg
# Extracted and saved face for person 549 at extracted_id_faces\person_549_id_face.jpg
# Extracted and saved face for person 550 at extracted_id_faces\person_550_id_face.jpg
# Extracted and saved face for person 551 at extracted_id_faces\person_551_id_face.jpg
# Extracted and saved face for person 552 at extracted_id_faces\person_552_id_face.jpg
# Extracted and saved face for person 553 at extracted_id_faces\person_553_id_face.jpg
# Extracted and saved face for person 554 at extracted_id_faces\person_554_id_face.jpg
# Extracted and saved face for person 555 at extracted_id_faces\person_555_id_face.jpg
# Extracted and saved face for person 556 at extracted_id_faces\person_556_id_face.jpg
# Extracted and saved face for person 557 at extracted_id_faces\person_557_id_face.jpg
# Extracted and saved face for person 558 at extracted_id_faces\person_558_id_face.jpg
# Extracted and saved face for person 559 at extracted_id_faces\person_559_id_face.jpg
# Extracted and saved face for person 560 at extracted_id_faces\person_560_id_face.jpg
# Extracted and saved face for person 561 at extracted_id_faces\person_561_id_face.jpg
# Extracted and saved face for person 562 at extracted_id_faces\person_562_id_face.jpg
# Extracted and saved face for person 563 at extracted_id_faces\person_563_id_face.jpg
# ...
# Extracted and saved face for person 566 at extracted_id_faces\person_566_id_face.jpg
# Extracted and saved face for person 567 at extracted_id_faces\person_567_id_face.jpg
# Extracted and saved face for person 568 at extracted_id_faces\person_568_id_face.jpg
# Extracted and saved face for person 569 at extracted_id_faces\person_569_id_face.jpg
# Extracted and saved face for person 570 at extracted_id_faces\person_570_id_face.jpg
# Extracted and saved face for person 571 at extracted_id_faces\person_571_id_face.jpg
# Extracted and saved face for person 572 at extracted_id_faces\person_572_id_face.jpg
# Extracted and saved face for person 573 at extracted_id_faces\person_573_id_face.jpg
# Extracted and saved face for person 574 at extracted_id_faces\person_574_id_face.jpg
# Extracted and saved face for person 575 at extracted_id_faces\person_575_id_face.jpg
# Extracted and saved face for person 576 at extracted_id_faces\person_576_id_face.jpg
# Extracted and saved face for person 577 at extracted_id_faces\person_577_id_face.jpg
# Extracted and saved face for person 578 at extracted_id_faces\person_578_id_face.jpg
# Extracted and saved face for person 579 at extracted_id_faces\person_579_id_face.jpg
# Extracted and saved face for person 580 at extracted_id_faces\person_580_id_face.jpg
# Extracted and saved face for person 581 at extracted_id_faces\person_581_id_face.jpg
# Extracted and saved face for person 582 at extracted_id_faces\person_582_id_face.jpg
# Extracted and saved face for person 583 at extracted_id_faces\person_583_id_face.jpg
# Extracted and saved face for person 584 at extracted_id_faces\person_584_id_face.jpg
# Extracted and saved face for person 585 at extracted_id_faces\person_585_id_face.jpg
# Extracted and saved face for person 586 at extracted_id_faces\person_586_id_face.jpg
# Extracted and saved face for person 587 at extracted_id_faces\person_587_id_face.jpg
# Extracted and saved face for person 588 at extracted_id_faces\person_588_id_face.jpg
# Extracted and saved face for person 589 at extracted_id_faces\person_589_id_face.jpg
# Extracted and saved face for person 590 at extracted_id_faces\person_590_id_face.jpg
# Extracted and saved face for person 591 at extracted_id_faces\person_591_id_face.jpg
# Extracted and saved face for person 592 at extracted_id_faces\person_592_id_face.jpg
# Extracted and saved face for person 593 at extracted_id_faces\person_593_id_face.jpg
# Extracted and saved face for person 594 at extracted_id_faces\person_594_id_face.jpg
# Extracted and saved face for person 595 at extracted_id_faces\person_595_id_face.jpg
# Extracted and saved face for person 596 at extracted_id_faces\person_596_id_face.jpg
# Extracted and saved face for person 597 at extracted_id_faces\person_597_id_face.jpg
# Extracted and saved face for person 598 at extracted_id_faces\person_598_id_face.jpg
# Extracted and saved face for person 599 at extracted_id_faces\person_599_id_face.jpg
# Extracted and saved face for person 600 at extracted_id_faces\person_600_id_face.jpg
# Extracted and saved face for person 601 at extracted_id_faces\person_601_id_face.jpg
# Extracted and saved face for person 602 at extracted_id_faces\person_602_id_face.jpg
# Extracted and saved face for person 603 at extracted_id_faces\person_603_id_face.jpg
# Extracted and saved face for person 604 at extracted_id_faces\person_604_id_face.jpg
# Extracted and saved face for person 605 at extracted_id_faces\person_605_id_face.jpg
# Extracted and saved face for person 606 at extracted_id_faces\person_606_id_face.jpg
# Extracted and saved face for person 607 at extracted_id_faces\person_607_id_face.jpg
# Extracted and saved face for person 608 at extracted_id_faces\person_608_id_face.jpg
# Extracted and saved face for person 609 at extracted_id_faces\person_609_id_face.jpg
# Extracted and saved face for person 610 at extracted_id_faces\person_610_id_face.jpg
# Extracted and saved face for person 611 at extracted_id_faces\person_611_id_face.jpg
# Extracted and saved face for person 612 at extracted_id_faces\person_612_id_face.jpg
# Extracted and saved face for person 613 at extracted_id_faces\person_613_id_face.jpg
# Extracted and saved face for person 614 at extracted_id_faces\person_614_id_face.jpg
# Extracted and saved face for person 615 at extracted_id_faces\person_615_id_face.jpg
# Extracted and saved face for person 616 at extracted_id_faces\person_616_id_face.jpg
# Extracted and saved face for person 617 at extracted_id_faces\person_617_id_face.jpg
# Extracted and saved face for person 618 at extracted_id_faces\person_618_id_face.jpg
# Extracted and saved face for person 619 at extracted_id_faces\person_619_id_face.jpg
# Extracted and saved face for person 620 at extracted_id_faces\person_620_id_face.jpg
# Extracted and saved face for person 621 at extracted_id_faces\person_621_id_face.jpg
# Extracted and saved face for person 622 at extracted_id_faces\person_622_id_face.jpg
# Extracted and saved face for person 623 at extracted_id_faces\person_623_id_face.jpg
# Extracted and saved face for person 624 at extracted_id_faces\person_624_id_face.jpg
# Extracted and saved face for person 625 at extracted_id_faces\person_625_id_face.jpg
# Extracted and saved face for person 626 at extracted_id_faces\person_626_id_face.jpg
# Extracted and saved face for person 627 at extracted_id_faces\person_627_id_face.jpg
# Extracted and saved face for person 628 at extracted_id_faces\person_628_id_face.jpg
# Extracted and saved face for person 629 at extracted_id_faces\person_629_id_face.jpg
# Extracted and saved face for person 630 at extracted_id_faces\person_630_id_face.jpg
# Extracted and saved face for person 631 at extracted_id_faces\person_631_id_face.jpg
# Extracted and saved face for person 632 at extracted_id_faces\person_632_id_face.jpg
# Extracted and saved face for person 633 at extracted_id_faces\person_633_id_face.jpg
# Extracted and saved face for person 634 at extracted_id_faces\person_634_id_face.jpg
# Extracted and saved face for person 635 at extracted_id_faces\person_635_id_face.jpg
# Extracted and saved face for person 636 at extracted_id_faces\person_636_id_face.jpg
# Extracted and saved face for person 637 at extracted_id_faces\person_637_id_face.jpg
# Extracted and saved face for person 638 at extracted_id_faces\person_638_id_face.jpg
# Extracted and saved face for person 639 at extracted_id_faces\person_639_id_face.jpg
# Extracted and saved face for person 640 at extracted_id_faces\person_640_id_face.jpg
# Extracted and saved face for person 641 at extracted_id_faces\person_641_id_face.jpg
# Extracted and saved face for person 642 at extracted_id_faces\person_642_id_face.jpg
# Extracted and saved face for person 643 at extracted_id_faces\person_643_id_face.jpg
# Extracted and saved face for person 644 at extracted_id_faces\person_644_id_face.jpg
# Extracted and saved face for person 645 at extracted_id_faces\person_645_id_face.jpg
# Extracted and saved face for person 646 at extracted_id_faces\person_646_id_face.jpg
# Extracted and saved face for person 647 at extracted_id_faces\person_647_id_face.jpg
# Extracted and saved face for person 648 at extracted_id_faces\person_648_id_face.jpg
# Extracted and saved face for person 649 at extracted_id_faces\person_649_id_face.jpg
# Extracted and saved face for person 650 at extracted_id_faces\person_650_id_face.jpg
# Extracted and saved face for person 651 at extracted_id_faces\person_651_id_face.jpg
# Extracted and saved face for person 652 at extracted_id_faces\person_652_id_face.jpg
# Extracted and saved face for person 653 at extracted_id_faces\person_653_id_face.jpg
# Extracted and saved face for person 654 at extracted_id_faces\person_654_id_face.jpg
# Extracted and saved face for person 655 at extracted_id_faces\person_655_id_face.jpg
# Extracted and saved face for person 656 at extracted_id_faces\person_656_id_face.jpg
# Extracted and saved face for person 657 at extracted_id_faces\person_657_id_face.jpg
# Extracted and saved face for person 658 at extracted_id_faces\person_658_id_face.jpg
# Extracted and saved face for person 659 at extracted_id_faces\person_659_id_face.jpg
# Extracted and saved face for person 660 at extracted_id_faces\person_660_id_face.jpg
# Extracted and saved face for person 661 at extracted_id_faces\person_661_id_face.jpg
# Extracted and saved face for person 662 at extracted_id_faces\person_662_id_face.jpg
# Extracted and saved face for person 663 at extracted_id_faces\person_663_id_face.jpg
# Extracted and saved face for person 664 at extracted_id_faces\person_664_id_face.jpg
# Extracted and saved face for person 665 at extracted_id_faces\person_665_id_face.jpg
# Extracted and saved face for person 666 at extracted_id_faces\person_666_id_face.jpg
# Extracted and saved face for person 667 at extracted_id_faces\person_667_id_face.jpg
# Extracted and saved face for person 668 at extracted_id_faces\person_668_id_face.jpg
# Extracted and saved face for person 669 at extracted_id_faces\person_669_id_face.jpg
# Extracted and saved face for person 670 at extracted_id_faces\person_670_id_face.jpg
# Extracted and saved face for person 671 at extracted_id_faces\person_671_id_face.jpg
# Extracted and saved face for person 672 at extracted_id_faces\person_672_id_face.jpg
# Extracted and saved face for person 673 at extracted_id_faces\person_673_id_face.jpg
# Extracted and saved face for person 674 at extracted_id_faces\person_674_id_face.jpg
# Extracted and saved face for person 675 at extracted_id_faces\person_675_id_face.jpg
# Extracted and saved face for person 676 at extracted_id_faces\person_676_id_face.jpg
# Extracted and saved face for person 677 at extracted_id_faces\person_677_id_face.jpg
# Extracted and saved face for person 678 at extracted_id_faces\person_678_id_face.jpg
# Extracted and saved face for person 679 at extracted_id_faces\person_679_id_face.jpg
# Extracted and saved face for person 680 at extracted_id_faces\person_680_id_face.jpg
# Extracted and saved face for person 681 at extracted_id_faces\person_681_id_face.jpg
# Extracted and saved face for person 682 at extracted_id_faces\person_682_id_face.jpg
# Extracted and saved face for person 683 at extracted_id_faces\person_683_id_face.jpg
# Extracted and saved face for person 684 at extracted_id_faces\person_684_id_face.jpg
# Extracted and saved face for person 685 at extracted_id_faces\person_685_id_face.jpg
# Extracted and saved face for person 686 at extracted_id_faces\person_686_id_face.jpg
# Extracted and saved face for person 687 at extracted_id_faces\person_687_id_face.jpg
# Extracted and saved face for person 688 at extracted_id_faces\person_688_id_face.jpg
# Extracted and saved face for person 689 at extracted_id_faces\person_689_id_face.jpg
# Extracted and saved face for person 690 at extracted_id_faces\person_690_id_face.jpg
# Extracted and saved face for person 691 at extracted_id_faces\person_691_id_face.jpg
# Extracted and saved face for person 692 at extracted_id_faces\person_692_id_face.jpg
# Extracted and saved face for person 693 at extracted_id_faces\person_693_id_face.jpg
# Extracted and saved face for person 694 at extracted_id_faces\person_694_id_face.jpg
# Extracted and saved face for person 695 at extracted_id_faces\person_695_id_face.jpg
# Extracted and saved face for person 696 at extracted_id_faces\person_696_id_face.jpg
# Extracted and saved face for person 697 at extracted_id_faces\person_697_id_face.jpg
# Extracted and saved face for person 698 at extracted_id_faces\person_698_id_face.jpg
# Extracted and saved face for person 699 at extracted_id_faces\person_699_id_face.jpg
# Extracted and saved face for person 700 at extracted_id_faces\person_700_id_face.jpg
# Extracted and saved face for person 701 at extracted_id_faces\person_701_id_face.jpg
# Extracted and saved face for person 702 at extracted_id_faces\person_702_id_face.jpg
# Extracted and saved face for person 703 at extracted_id_faces\person_703_id_face.jpg
# Extracted and saved face for person 704 at extracted_id_faces\person_704_id_face.jpg
# Extracted and saved face for person 705 at extracted_id_faces\person_705_id_face.jpg
# Extracted and saved face for person 706 at extracted_id_faces\person_706_id_face.jpg
# Extracted and saved face for person 707 at extracted_id_faces\person_707_id_face.jpg
# Extracted and saved face for person 708 at extracted_id_faces\person_708_id_face.jpg
# Extracted and saved face for person 709 at extracted_id_faces\person_709_id_face.jpg
# Extracted and saved face for person 710 at extracted_id_faces\person_710_id_face.jpg
# Extracted and saved face for person 711 at extracted_id_faces\person_711_id_face.jpg
# Extracted and saved face for person 712 at extracted_id_faces\person_712_id_face.jpg
# Extracted and saved face for person 713 at extracted_id_faces\person_713_id_face.jpg
# Extracted and saved face for person 714 at extracted_id_faces\person_714_id_face.jpg
# Extracted and saved face for person 715 at extracted_id_faces\person_715_id_face.jpg
# Extracted and saved face for person 716 at extracted_id_faces\person_716_id_face.jpg
# Extracted and saved face for person 717 at extracted_id_faces\person_717_id_face.jpg
# Extracted and saved face for person 718 at extracted_id_faces\person_718_id_face.jpg
# Extracted and saved face for person 719 at extracted_id_faces\person_719_id_face.jpg
# Extracted and saved face for person 720 at extracted_id_faces\person_720_id_face.jpg
# Extracted and saved face for person 721 at extracted_id_faces\person_721_id_face.jpg
# Extracted and saved face for person 722 at extracted_id_faces\person_722_id_face.jpg
# Extracted and saved face for person 723 at extracted_id_faces\person_723_id_face.jpg
# Extracted and saved face for person 724 at extracted_id_faces\person_724_id_face.jpg
# Extracted and saved face for person 725 at extracted_id_faces\person_725_id_face.jpg
# Extracted and saved face for person 726 at extracted_id_faces\person_726_id_face.jpg
# No face detected for person 727. Saved original image to extracted_id_faces\person_727_failed.jpg
# Extracted and saved face for person 728 at extracted_id_faces\person_728_id_face.jpg
# Extracted and saved face for person 729 at extracted_id_faces\person_729_id_face.jpg
# Extracted and saved face for person 730 at extracted_id_faces\person_730_id_face.jpg
# Extracted and saved face for person 731 at extracted_id_faces\person_731_id_face.jpg
# Extracted and saved face for person 732 at extracted_id_faces\person_732_id_face.jpg
# Extracted and saved face for person 733 at extracted_id_faces\person_733_id_face.jpg
# Extracted and saved face for person 734 at extracted_id_faces\person_734_id_face.jpg
# Extracted and saved face for person 735 at extracted_id_faces\person_735_id_face.jpg
# Extracted and saved face for person 736 at extracted_id_faces\person_736_id_face.jpg
# Extracted and saved face for person 737 at extracted_id_faces\person_737_id_face.jpg
# Extracted and saved face for person 738 at extracted_id_faces\person_738_id_face.jpg
# Extracted and saved face for person 739 at extracted_id_faces\person_739_id_face.jpg
# Extracted and saved face for person 740 at extracted_id_faces\person_740_id_face.jpg
# Extracted and saved face for person 741 at extracted_id_faces\person_741_id_face.jpg
# Extracted and saved face for person 742 at extracted_id_faces\person_742_id_face.jpg
# Extracted and saved face for person 743 at extracted_id_faces\person_743_id_face.jpg
# Extracted and saved face for person 744 at extracted_id_faces\person_744_id_face.jpg
# Extracted and saved face for person 745 at extracted_id_faces\person_745_id_face.jpg
# Extracted and saved face for person 746 at extracted_id_faces\person_746_id_face.jpg
# Extracted and saved face for person 747 at extracted_id_faces\person_747_id_face.jpg
# Extracted and saved face for person 748 at extracted_id_faces\person_748_id_face.jpg
# Extracted and saved face for person 749 at extracted_id_faces\person_749_id_face.jpg
# Extracted and saved face for person 750 at extracted_id_faces\person_750_id_face.jpg
# Extracted and saved face for person 751 at extracted_id_faces\person_751_id_face.jpg
# Extracted and saved face for person 752 at extracted_id_faces\person_752_id_face.jpg
# Face extraction complete! Check extraction_log.txt and debug_log.txt for details.

# %%
import os
import pandas as pd

# Load the original CSV
csv_path = "updated_data.csv"  # Replace with your updated CSV file path
df = pd.read_csv(csv_path)

# Define directories
extracted_dir = "extracted_id_faces"
output_db_path = "face_id_database.csv"

# Create a dictionary mapping ID to Face_Photo path
id_to_face_photo = dict(zip(df['ID'], df['IMAGE']))

# Initialize list to store database entries
database_entries = []

# Scan extracted faces folder
for filename in os.listdir(extracted_dir):
    if filename.endswith("_id_face.jpg"):
        # Extract ID from filename (e.g., "person_123_id_face.jpg" -> "123")
        try:
            id_str = filename.replace("person_", "").replace("_id_face.jpg", "")
            person_id = int(id_str)
        except ValueError:
            print(f"Skipping invalid filename: {filename}")
            continue

        # Check if ID exists in the original CSV
        if person_id in id_to_face_photo:
            extracted_path = os.path.join(extracted_dir, filename)
            face_photo_path = id_to_face_photo[person_id]
            database_entries.append({
                "ID": person_id,
                "Extracted_Face_Path": extracted_path,
                "Face_Photo_Path": face_photo_path
            })
        else:
            print(f"ID {person_id} from {filename} not found in CSV, skipping.")

# Create DataFrame and save to CSV
if database_entries:
    db_df = pd.DataFrame(database_entries)
    db_df.to_csv(output_db_path, index=False)
    print(f"Database created successfully with {len(database_entries)} entries at {output_db_path}")
else:
    print("No valid extracted faces found to create database.")

print("Database creation complete!")
# Out:
# Database created successfully with 728 entries at face_id_database.csv
# Database creation complete!

# %%
# import os
# import cv2
# import pandas as pd
# import numpy as np
# from mtcnn import MTCNN

# # Load CSV
# csv_path = "updated_data.csv"  # Replace with your updated CSV file path
# df = pd.read_csv(csv_path)

# # Create output directory
# output_dir = "extracted_id_faces"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Preprocessing and alignment function
# def preprocess_and_align_id_face(img):
#     # Convert to RGB for initial processing (handle colored ID image)
#     if len(img.shape) == 2:
#         img_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
#     else:
#         img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#     # Detect face in the colored ID image
#     detector = MTCNN()
#     faces = detector.detect_faces(img_rgb)

#     if not faces:
#         print(f"No face detected initially, trying with adjusted parameters...")
#         detector.min_face_size = 20  # Reduce minimum face size
#         faces = detector.detect_faces(img_rgb)
#         if not faces:
#             print(f"Failed to detect face after adjustments.")
#             return None

#     # Use first detected face (black-and-white photo within ID)
#     x, y, w, h = faces[0]['box']
#     x, y = max(0, x), max(0, y)
#     face_img = img_rgb[y:y+h, x:x+w] if y+h <= img_rgb.shape[0] and x+w <= img_rgb.shape[1] else img_rgb[max(0, y):min(img_rgb.shape[0], y+h), max(0, x):min(img_rgb.shape[1], x+w)]

#     # Convert cropped face to grayscale (since it's black-and-white)
#     face_gray = cv2.cvtColor(face_img, cv2.COLOR_RGB2GRAY)

#     # Enhance lighting with CLAHE
#     clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
#     enhanced = clahe.apply(face_gray)
#     denoised = cv2.GaussianBlur(enhanced, (5, 5), 0)

#     # Get landmarks for alignment (eyes)
#     faces_gray = detector.detect_faces(cv2.cvtColor(denoised, cv2.COLOR_GRAY2RGB))
#     if not faces_gray or not faces_gray[0]['keypoints']:
#         print(f"No landmarks detected for alignment.")
#         return cv2.cvtColor(denoised, cv2.COLOR_GRAY2RGB)  # Fallback without rotation

#     landmarks = faces_gray[0]['keypoints']
#     left_eye = landmarks['left_eye']
#     right_eye = landmarks['right_eye']

#     # Calculate rotation angle based on eye positions
#     dy = right_eye[1] - left_eye[1]
#     dx = right_eye[0] - left_eye[0]
#     angle = np.degrees(np.arctan2(dy, dx)) - 180  # Align eyes horizontally

#     # Rotate image
#     center = (denoised.shape[1] // 2, denoised.shape[0] // 2)
#     rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
#     rotated_face = cv2.warpAffine(denoised, rotation_matrix, (denoised.shape[1], denoised.shape[0]))

#     # Convert back to RGB for output
#     rgb_face = cv2.cvtColor(rotated_face, cv2.COLOR_GRAY2RGB)
#     return cv2.resize(rgb_face, (224, 224))  # Resize to 224x224

# # Process each ID image in CSV
# for index, row in df.iterrows():
#     id_image_path = row['ID_IMAGE']
#     person_id = row['ID']

#     # Load image
#     img = cv2.imread(id_image_path)
#     if img is None:
#         print(f"Error loading image: {id_image_path}")
#         continue

#     # Extract and preprocess face
#     preprocessed_face = preprocess_and_align_id_face(img)
#     if preprocessed_face is not None:
#         # Save extracted face
#         output_path = os.path.join(output_dir, f"person_{person_id}_id_face.jpg")
#         cv2.imwrite(output_path, preprocessed_face)
#         print(f"Extracted and saved face for person {person_id} from {id_image_path}")
#     else:
#         print(f"Failed to process face for person {person_id} from {id_image_path}")

# print("Face extraction complete!")
